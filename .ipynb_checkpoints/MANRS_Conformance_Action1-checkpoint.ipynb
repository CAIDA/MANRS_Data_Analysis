# %% [markdown]
# # Are MANRS ASes conformant to Action 1?
# MANRS action 1 states that MANRS networks should filter incorrect announcements from their customers.
#
# Paper: https://www.caida.org/catalog/papers/2022_mind_your_manrs/mind_your_manrs.pdf

# %%
import pandas as pd
import os
import multiprocessing as mp
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import requests
from collections import defaultdict
import bz2
import lz4.frame
import urllib
import gzip

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # MANRS ASes
#
# Parse ASes in the MANRS Network Operators Program. CSV files can be downloaded from:
# https://www.manrs.org/netops/participants/

# %%
manrs = []
manrs_org = {}
manrs_org2as = defaultdict(list)
with open('manrs_isps.csv', 'rt') as f:
    for line in f:
        data = line.strip().split(',')
        if len(data) < 7:
            continue
        asns = data[2].split(';')
        for i in asns:
            try:
                manrs.append(int(i))
                manrs_org[int(i)] = data[0]
                manrs_org2as[data[0]].append(int(i))
            except:
                pass

# %%
manrscdn = []
with open('manrs_cdns.csv', 'rt') as f:
    for line in f:
        data = line.strip().split(',')
        if len(data) < 7:
            continue
        asns = data[1].split(';')
        for i in asns:
            if not i.isdigit():
                continue
            try:
                manrscdn.append(int(i))
                manrs_org[int(i)] = data[0]
                manrs_org2as[data[0]].append(int(i))
            except:
                pass

# %%
manrsas = manrs + manrscdn

# %% [markdown]
# ## Group by AS size (number of customers)
#
# ### Parse CAIDA AS Relationship Dataset
#
# CAIDA AS Relationship Dataset can be downloaded from:
# https://www.caida.org/catalog/datasets/as-relationships/
# Use files with the extension `.as-rel.txt.bz2`

# %%
path = '20220301.as-rel.txt.bz2'   #replace with new file
as_cust = defaultdict(int)
with bz2.open(path, 'rt') as file:
    for line in file:
        if line.startswith('#'):
            continue
        data = line.strip().split('|')
        AS1 = int(data[0])
        AS2 = int(data[1])
        rel = data[2]
        if rel == '1':
            as_cust[AS2] += 1
        elif rel == '-1':
            as_cust[AS1] += 1

# %%
cust_deg = pd.DataFrame(as_cust.items(), columns=['asn', 'cust'])
small = cust_deg[cust_deg.cust <= 2]['asn']
medium = cust_deg[(cust_deg.cust > 2) & (cust_deg.cust < 180)]['asn']
large = cust_deg[cust_deg.cust >= 180]['asn']

# %%
cust_deg
# Out:
#           asn  cust
# 0           1     2
# 1           2     2
# 2           4     1
# 3           5     2
# 4           6     1
# ...       ...   ...
# 11412  399888     1
# 11413  399895     1
# 11414  399998     1
# 11415  400282     1
# 11416  401307    12
#
# [11417 rows x 2 columns]

# %% [markdown]
# ### separate MANRS and non-MANRS ASes into small, medium, and large catgories
#
# small ASes have # of customers < 2
# medium ASes have # of customers between 2 and 180
# Large ASes have # of customers > 180

# %%
medium_manrs = set(manrsas).intersection(set(medium))
large_manrs = set(manrsas).intersection(set(large))
small_manrs = set(manrsas) - medium_manrs - large_manrs

# %%
print(len(small_manrs), len(medium_manrs), len(large_manrs))
# Out:
# 520 319 24

# %%
small_non_manrs = set(small) - small_manrs
medium_non_manrs = set(medium) - medium_manrs
large_non_manrs = set(large) - large_manrs

# %% [markdown]
# # AS Customer List
#
# Using the CAIDA AS Relationship Dataset, construct a list of customers for all ASes
#
# CAIDA AS Relationship Dataset can be downloaded from:
# https://www.caida.org/catalog/datasets/as-relationships/
# Use files with the extension `.as-rel.txt.bz2`

# %%
path = '20220501.as-rel.txt.bz2'   #replace with new file
as_rel = defaultdict(lambda: defaultdict(set))
with bz2.open(path, 'rt') as file:
    for line in file:
        if line.startswith('#'):
            continue
        data = line.strip().split('|')
        AS1 = int(data[0])
        AS2 = int(data[1])
        rel = data[2]
        if rel == '0':
            as_rel[AS1]['peer'].add(AS2)
            as_rel[AS2]['peer'].add(AS1)
        elif rel == '1':
            as_rel[AS1]['provider'].add(AS2)
            as_rel[AS2]['customer'].add(AS1)
        elif rel == '-1':
            as_rel[AS1]['customer'].add(AS2)
            as_rel[AS2]['provider'].add(AS1)

# %% [markdown]
# # RPKI and IRR statuses of prefixes propagated by MANRS and non-MANRS networks
#
# ## Process data from the Internet Health Report
# IHR data can be downloaded from:
# https://ihr-archive.iijlab.net/ihr/rov/
#
# IHR also provides a dashboard:
# https://ihr.iijlab.net/ihr/en-us/rov

# %%
ihrurl = 'https://ihr-archive.iijlab.net/ihr/rov/2022/05/01/ihr_rov_2022-05-01.csv.lz4' #replace with new file

# %%
def process_ihr(url):
    try:
        handle = urllib.request.urlopen(url)
    except:
        print('URL not found', url)
        raise Exception
        return
    with lz4.frame.open(handle) as f:
        df = pd.read_csv(f)
        transitdf = df[df.asn_id != df.originasn_id]
        return transitdf

# %%
transitdf = process_ihr(ihrurl)
transitdf = transitdf[transitdf.af == 4]

# %% [markdown]
# ## Explanation of column names
# `prefix`: IP prefix observed in BGP, announced by the AS denoted in `originasn_id`
# `hege`: AS hegemony value, not used in conformance analysis. Ignore column.
# `visibility`: visibility of the prefix in RouteViews and RIPE RIS collectors, not used in conformance analysis. Ignore column.
# `moas`: Whether the `prefix` is announced by multiple origin ASes. `t` for True and `f` for False. Ignore Column.
# `asn_id`: the AS propagating the `prefix`. It is an upstream AS of `originasn_id`
# `originasn_id`: the AS announcing the `prefix`

# %%
transitdf
# Out:
#                  id                 timebin            prefix      hege  af  \
# 691981   1415697056  2022-05-01 00:00:00+00   165.156.17.0/24  0.027211   4
# 691983   1415697054  2022-05-01 00:00:00+00  156.154.101.0/24  0.027211   4
# 691985   1415697052  2022-05-01 00:00:00+00      64.6.65.0/24  0.040816   4
# 691987   1415697050  2022-05-01 00:00:00+00   156.154.64.0/24  0.040816   4
# 691989   1415697048  2022-05-01 00:00:00+00   204.74.112.0/24  0.040816   4
# ...             ...                     ...               ...       ...  ..
# 5294710  1411094454  2022-05-01 00:00:00+00     1.73.208.0/20  0.047619   4
# 5294712  1411094452  2022-05-01 00:00:00+00      1.66.92.0/24  0.258503   4
# 5294713  1411094451  2022-05-01 00:00:00+00      1.66.92.0/24  0.367347   4
# 5294714  1411094450  2022-05-01 00:00:00+00      1.66.92.0/24  0.006803   4
# 5294716  1411094448  2022-05-01 00:00:00+00       1.32.0.0/19  0.523810   4
#
# ...

# %% [markdown]
# ## Compute AS relationship between the origin AS and the propagating AS of the prefix
#
# AS relationship between `asn_id` and `originasn_id`
# `relationship` value 'customer' means:  `originasn_id` is a customer of `asn_id`

# %%
def lookup_relationship(x):
    origin = x['originasn_id']
    transit = x['asn_id']
    if transit in as_rel:
        if origin in as_rel[transit]['peer']:
            return 'peer'
        elif origin in as_rel[transit]['customer']:
            return 'customer'
        elif origin in as_rel[transit]['provider']:
            return 'provider'
    return 'norel'

# %%
transitdf['relationship'] = transitdf.apply(lookup_relationship, axis=1)

# %%
transitdf
# Out:
#                  id                 timebin            prefix      hege  af  \
# 691981   1415697056  2022-05-01 00:00:00+00   165.156.17.0/24  0.027211   4
# 691983   1415697054  2022-05-01 00:00:00+00  156.154.101.0/24  0.027211   4
# 691985   1415697052  2022-05-01 00:00:00+00      64.6.65.0/24  0.040816   4
# 691987   1415697050  2022-05-01 00:00:00+00   156.154.64.0/24  0.040816   4
# 691989   1415697048  2022-05-01 00:00:00+00   204.74.112.0/24  0.040816   4
# ...             ...                     ...               ...       ...  ..
# 5294710  1411094454  2022-05-01 00:00:00+00     1.73.208.0/20  0.047619   4
# 5294712  1411094452  2022-05-01 00:00:00+00      1.66.92.0/24  0.258503   4
# 5294713  1411094451  2022-05-01 00:00:00+00      1.66.92.0/24  0.367347   4
# 5294714  1411094450  2022-05-01 00:00:00+00      1.66.92.0/24  0.006803   4
# 5294716  1411094448  2022-05-01 00:00:00+00       1.32.0.0/19  0.523810   4
#
# ...

# %% [markdown]
# ## remove bogon ASN

# %%
len(transitdf) - len(transitdf[((transitdf.asn_id != 23456) & ((transitdf.asn_id < 64496) | (transitdf.asn_id > 131071)) & ((transitdf.asn_id < 4200000000) | (transitdf.asn_id > 4294967295))) & ((transitdf.originasn_id != 23456) & ((transitdf.originasn_id < 64496) | (transitdf.originasn_id > 131071)) & ((transitdf.originasn_id < 4200000000) | (transitdf.originasn_id > 4294967295)))])
# Out:
# 763

# %%
transitdf = transitdf[((transitdf.asn_id != 23456) & ((transitdf.asn_id < 64496) | (transitdf.asn_id > 131071)) & ((transitdf.asn_id < 4200000000) | (transitdf.asn_id > 4294967295))) & ((transitdf.originasn_id != 23456) & ((transitdf.originasn_id < 64496) | (transitdf.originasn_id > 131071)) & ((transitdf.originasn_id < 4200000000) | (transitdf.originasn_id > 4294967295)))]

# %%
transitdf
# Out:
#                  id                 timebin            prefix      hege  af  \
# 691981   1415697056  2022-05-01 00:00:00+00   165.156.17.0/24  0.027211   4
# 691983   1415697054  2022-05-01 00:00:00+00  156.154.101.0/24  0.027211   4
# 691985   1415697052  2022-05-01 00:00:00+00      64.6.65.0/24  0.040816   4
# 691987   1415697050  2022-05-01 00:00:00+00   156.154.64.0/24  0.040816   4
# 691989   1415697048  2022-05-01 00:00:00+00   204.74.112.0/24  0.040816   4
# ...             ...                     ...               ...       ...  ..
# 5294710  1411094454  2022-05-01 00:00:00+00     1.73.208.0/20  0.047619   4
# 5294712  1411094452  2022-05-01 00:00:00+00      1.66.92.0/24  0.258503   4
# 5294713  1411094451  2022-05-01 00:00:00+00      1.66.92.0/24  0.367347   4
# 5294714  1411094450  2022-05-01 00:00:00+00      1.66.92.0/24  0.006803   4
# 5294716  1411094448  2022-05-01 00:00:00+00       1.32.0.0/19  0.523810   4
#
# ...

# %% [markdown]
# ## remove MANRS AS from originasn_id
#
# MANRS ASes should not announce prefixes that are neither RPKI valid nor IRR valid. We study their prefix announcing behavior in Action 4 conformance analysis. Here we remove them.

# %%
len(transitdf[transitdf.originasn_id.isin(manrsas)])
# Out:
# 176842

# %%
transitdf = transitdf[~transitdf.originasn_id.isin(manrsas)]

# %%
transitdf
# Out:
#                  id                 timebin            prefix      hege  af  \
# 687287   1290292883  2022-03-27 00:00:00+00   165.156.17.0/24  0.050000   4
# 687289   1290292881  2022-03-27 00:00:00+00  156.154.101.0/24  0.041667   4
# 687291   1290292879  2022-03-27 00:00:00+00   156.154.64.0/24  0.058333   4
# 687294   1290292876  2022-03-27 00:00:00+00   204.74.112.0/24  0.058333   4
# 687296   1290292874  2022-03-27 00:00:00+00      64.6.65.0/24  0.058333   4
# ...             ...                     ...               ...       ...  ..
# 5519453  1285460852  2022-03-27 00:00:00+00     31.31.48.0/20  0.225000   4
# 5519454  1285460851  2022-03-27 00:00:00+00     31.31.48.0/20  0.008333   4
# 5519510  1285460795  2022-03-27 00:00:00+00      5.183.4.0/24  0.325000   4
# 5519511  1285460794  2022-03-27 00:00:00+00      5.183.4.0/24  0.250000   4
# 5519512  1285460793  2022-03-27 00:00:00+00      5.183.4.0/24  0.708333   4
#
# ...

# %%
manrs_transit = transitdf[transitdf.asn_id.isin(manrsas)]
non_manrs_transit = transitdf[~transitdf.asn_id.isin(manrsas)]

# %%
manrs_transit['nettype'] = manrs_transit['asn_id'].apply(lambda x: 'CDN' if x in manrscdn else 'ISP')
# Out:
# /home/c4du/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
small_manrs_transit = manrs_transit[manrs_transit.asn_id.isin(small)]
medium_manrs_transit = manrs_transit[manrs_transit.asn_id.isin(medium)]
large_manrs_transit = manrs_transit[manrs_transit.asn_id.isin(large)]

# %%
small_non_manrs_transit = non_manrs_transit[non_manrs_transit.asn_id.isin(small)]
medium_non_manrs_transit = non_manrs_transit[non_manrs_transit.asn_id.isin(medium)]
large_non_manrs_transit = non_manrs_transit[non_manrs_transit.asn_id.isin(large)]

# %% [markdown]
# ## RPKI

# %% [markdown]
# ### Does MANRS networks originate more prefixes with RPKI record?

# %%
manrs_transit_rpki = manrs_transit.groupby(['asn_id', 'rpki_status']).size().unstack(fill_value=0).reset_index()
manrs_transit_rpki['rpki_percent'] = (1-manrs_transit_rpki['NotFound']/manrs_transit_rpki[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1))*100

# %%
manrs_transit_rpki['totalPO'] = manrs_transit_rpki[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1)

# %%
manrs_transit_rpki[manrs_transit_rpki.asn_id == 174]
# Out:
# rpki_status  asn_id  Invalid  Invalid,more-specific  NotFound   Valid  \
# 2               174        2                      0    303396  154378
#
# rpki_status  rpki_percent  totalPO
# 2               33.723917   457776

# %%
non_manrs_transit_rpki = non_manrs_transit.groupby(['asn_id', 'rpki_status']).size().unstack(fill_value=0).reset_index()
non_manrs_transit_rpki['rpki_percent'] = (1-non_manrs_transit_rpki['NotFound']/non_manrs_transit_rpki[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1))*100

# %%
non_manrs_transit_rpki['totalPO'] = non_manrs_transit_rpki[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1)

# %%
non_manrs_transit_rpki
# Out:
# rpki_status   asn_id  Invalid  Invalid,more-specific  NotFound  Valid  \
# 0                  1        0                      0         4      0
# 1                  2        0                      0         0     13
# 2                  5        0                      0         0      1
# 3                  8        0                      0         1      0
# 4                  9        0                      0         1      0
# ...              ...      ...                    ...       ...    ...
# 10710         655798        0                      0         0      1
# 10711         655799        0                      0         0      1
# 10712         655980        0                      0         0      1
# 10713        1349222        0                      0         0      1
# 10714        1696969        0                      0         2      0
#
# rpki_status  rpki_percent  totalPO
# 0                     0.0        4
# 1                   100.0       13
# ...

# %% [raw]
# plt.plot(np.sort(manrs_transit_rpki['rpki_percent']), np.linspace(0,1,len(manrs_transit_rpki)), label='MANRS')
# plt.plot(np.sort(non_manrs_transit_rpki['rpki_percent']), np.linspace(0,1,len(non_manrs_transit_rpki)), label='non-MANRS')
# plt.xlabel('Percent of propagated prefixes with RPKI records')
# plt.ylabel('CDF')
# plt.legend()
# plt.grid()

# %%
small_manrs_transit_rpki = manrs_transit_rpki[manrs_transit_rpki.asn_id.isin(small)]
medium_manrs_transit_rpki = manrs_transit_rpki[manrs_transit_rpki.asn_id.isin(medium)]
large_manrs_transit_rpki = manrs_transit_rpki[manrs_transit_rpki.asn_id.isin(large)]

small_non_manrs_transit_rpki = non_manrs_transit_rpki[non_manrs_transit_rpki.asn_id.isin(small)]
medium_non_manrs_transit_rpki = non_manrs_transit_rpki[non_manrs_transit_rpki.asn_id.isin(medium)]
large_non_manrs_transit_rpki = non_manrs_transit_rpki[non_manrs_transit_rpki.asn_id.isin(large)]

# %%
# small_manrs_transit_rpki = small_manrs_transit.groupby(['asn_id', 'rpki_status']).size().unstack(fill_value=0)
# small_manrs_transit_rpki['rpki_percent'] = (1-small_manrs_transit_rpki['NotFound']/small_manrs_transit_rpki.sum(axis=1))*100

# medium_manrs_transit_rpki = medium_manrs_transit.groupby(['asn_id', 'rpki_status']).size().unstack(fill_value=0)
# medium_manrs_transit_rpki['rpki_percent'] = (1-medium_manrs_transit_rpki['NotFound']/medium_manrs_transit_rpki.sum(axis=1))*100

# large_manrs_transit_rpki = large_manrs_transit.groupby(['asn_id', 'rpki_status']).size().unstack(fill_value=0)
# large_manrs_transit_rpki['rpki_percent'] = (1-large_manrs_transit_rpki['NotFound']/large_manrs_transit_rpki.sum(axis=1))*100

# %%
# small_non_manrs_transit_rpki = small_non_manrs_transit.groupby(['asn_id', 'rpki_status']).size().unstack(fill_value=0)
# small_non_manrs_transit_rpki['rpki_percent'] = (1-small_non_manrs_transit_rpki['NotFound']/small_non_manrs_transit_rpki.sum(axis=1))*100

# medium_non_manrs_transit_rpki = medium_non_manrs_transit.groupby(['asn_id', 'rpki_status']).size().unstack(fill_value=0)
# medium_non_manrs_transit_rpki['rpki_percent'] = (1-medium_non_manrs_transit_rpki['NotFound']/medium_non_manrs_transit_rpki.sum(axis=1))*100

# large_non_manrs_transit_rpki = large_non_manrs_transit.groupby(['asn_id', 'rpki_status']).size().unstack(fill_value=0)
# large_non_manrs_transit_rpki['rpki_percent'] = (1-large_non_manrs_transit_rpki['NotFound']/large_non_manrs_transit_rpki.sum(axis=1))*100

# %% [raw]
# #plt.figure(figsize=(8,6))
# plt.plot(np.sort(small_manrs_transit_rpki['rpki_percent']), np.linspace(0,1,len(small_manrs_transit_rpki)), label='small MANRS', linestyle='-')
# plt.plot(np.sort(small_non_manrs_transit_rpki['rpki_percent']), np.linspace(0,1,len(small_non_manrs_transit_rpki)), label='small non-MANRS', linestyle='-')
# plt.plot(np.sort(medium_manrs_transit_rpki['rpki_percent']), np.linspace(0,1,len(medium_manrs_transit_rpki)), label='medium MANRS', linestyle='--')
# plt.plot(np.sort(medium_non_manrs_transit_rpki['rpki_percent']), np.linspace(0,1,len(medium_non_manrs_transit_rpki)), label='medium non-MANRS', linestyle='--')
# plt.plot(np.sort(large_manrs_transit_rpki['rpki_percent']), np.linspace(0,1,len(large_manrs_transit_rpki)), label='large MANRS', linestyle='-.')
# plt.plot(np.sort(large_non_manrs_transit_rpki['rpki_percent']), np.linspace(0,1,len(large_non_manrs_transit_rpki)), label='large non-MANRS', linestyle='-.')
# plt.xlabel('Percent of propagated prefixes with RPKI records')
# plt.ylabel('CDF')
# #plt.xlim(80,105)
# plt.legend()
# plt.grid()

# %% [markdown]
# not all ASes of a network has to register in RPKI
# still have small ASes register RPKI, beyond manrs
# common ownership of those ASes
# siblings of registered manrs ASes

# %% [markdown]
# ### Sibling ASes of MANRS networks

# %%
path = '20220401.as-org2info.txt'
mapping = {}
companyname = {}
org2as = defaultdict(list)

with open(path, 'rt') as as2org:
    for line in as2org:
        l = line.strip('\n').split('|')
        asn = None
        if l[0].isdigit():
            asn = l[0]
            mapping[int(asn)] = l[3]
        elif len(l) == 5:
            companyname[l[0]] = (l[2], l[3])
    for i in mapping:
        orgname = companyname[mapping[i]]
        mapping[i] = orgname
        org2as[orgname].append(i)

# %% [markdown]
# manually merge china telecom

# %%
manrs_org2as.pop('China Telecom Global Limited', None)
# Out:
# [23764]

# %%
manrs_org2as['China Telecom']
# Out:
# [4809, 4134]

# %%
manrs_org2as
# Out:
# defaultdict(list,
#             {'GIBIRNET': [208972],
#              'Windstream Communication Limited': [139009],
#              'Sndc communication Pvt Ltd': [142419],
#              'SUPER CONNECT TELECOM LTDA': [262300],
#              'Valor Christian High School': [36289],
#              'Farzanegan Pars': [200370],
#              'BT Ireland': [2110],
#              'CEDIA': [61468, 27841, 27820, 262212],
#              'TOHUNET': [140731],
#              'Cyber Internet Telecom': [262565],
#              'CD ONE Corporation do Brasil': [52818],
#              'TDC': [3292],
#              '76 Telecom Telecomunicações Ltda': [262760, 262363],
#              'Implex.net': [21709],
#              'TECMAIS TELECOMUNICAÇÕES': [61785],
#              'CLICK CONNECT': [267113],
#              'Radar Internet': [262880],
#              'URAN Association': [12687],
#              'nts workspace ag': [15576, 39040],
#              'MobiCom Corporation': [55805, 9484],
# ...

# %%
sibling_not_in_manrs = defaultdict(list)
for i in manrs_org2as:
    registered_AS = manrs_org2as[i]
    marker = False
    for rep_AS in registered_AS:
        if marker == True:
            break
        if rep_AS in mapping:
            siblings = org2as[mapping[rep_AS]]
            for j in siblings:
                if j not in registered_AS:
                    sibling_not_in_manrs[i].append(j)
            marker = True

# %%
org2as[mapping[20940]]
# Out:
# [20940,
#  21342,
#  21357,
#  21399,
#  31107,
#  31108,
#  31109,
#  31110,
#  31377,
#  33905,
#  34164,
#  34850,
#  35204,
#  39836,
#  43639,
#  48163,
#  49249,
#  49846,
#  200005,
#  213120]

# %%
len(sibling_not_in_manrs)
# Out:
# 204

# %%
sibling_not_in_manrs
# Out:
# defaultdict(list,
#             {'GIBIRNET': [59510],
#              'Windstream Communication Limited': [59203],
#              'Sndc communication Pvt Ltd': [38230,
#               134828,
#               136918,
#               137490,
#               137509,
#               137520,
#               139308,
#               141702,
#               141703,
#               142039,
#               142289,
#               142597,
#               142598,
#               142632,
#               142635,
#               149434,
#               149435],
#              'BT Ireland': [3286, 24622],
#              'TOHUNET': [132623,
#               133555,
#               134477,
#               134488,
#               134708,
#               134993,
#               136591,
#               137835,
#               139231,
#               139317,
#               139734,
#               140506,
#               140961,
#               141429,
#               141445,
#               141694,
# ...

# %%
sibling_actually_not_in_manrs = defaultdict(list)
for i in sibling_not_in_manrs:
    for AS in sibling_not_in_manrs[i]:
        if AS not in manrs:
            sibling_actually_not_in_manrs[i].append(AS)

# %%
len(sibling_actually_not_in_manrs)
# Out:
# 199

# %%
sibling_actually_not_in_manrs['Comcast']
# Out:
# [6161,
#  7757,
#  7853,
#  13385,
#  14668,
#  16748,
#  23253,
#  23266,
#  33351,
#  33542,
#  33658,
#  33663,
#  36196,
#  36377,
#  53297,
#  393232,
#  395974,
#  395976,
#  395980,
#  396017,
#  396019,
#  396021,
#  396415]

# %%
sibling_dist = {}
for i in sibling_actually_not_in_manrs:
    sibling_dist[i] = len(sibling_actually_not_in_manrs[i])

# %%
plt.plot(np.sort(list(sibling_dist.values())), np.linspace(0,1,len(sibling_dist)))
plt.xscale('log')
plt.xlabel('number of sibling ASes not in MANRS')
plt.ylabel('CDF')
plt.grid()

# %%
sibling_actually_not_in_manrs['Comcast']
# Out:
# [6161,
#  7757,
#  7853,
#  13385,
#  14668,
#  16748,
#  23253,
#  23266,
#  33351,
#  33542,
#  33658,
#  33663,
#  36196,
#  36377,
#  53297,
#  393232,
#  395974,
#  395976,
#  395980,
#  396017,
#  396019,
#  396021,
#  396415]

# %%
as_non_manrs_sibling = set()
for i in sibling_actually_not_in_manrs:
    for j in sibling_actually_not_in_manrs[i]:
        as_non_manrs_sibling.add(j)

# %% [markdown]
# distribution

# %%
len(as_non_manrs_sibling)
# Out:
# 1489

# %%
all(i not in manrs for i in as_non_manrs_sibling)
# Out:
# True

# %% [markdown]
# ### Does MANRS originate more RPKI valids than non_MANRS?

# %%
manrs_transit_rpki['valid_percent'] = (manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1)/manrs_transit_rpki[['Invalid','Invalid,more-specific','Valid', 'NotFound']].sum(axis=1))*100
non_manrs_transit_rpki['valid_percent'] = (non_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1)/non_manrs_transit_rpki[['Invalid','Invalid,more-specific','Valid', 'NotFound']].sum(axis=1))*100
#sibling_non_manrs_transit_rpki['valid_percent'] = (sibling_non_manrs_transit_rpki['Valid']/sibling_non_manrs_transit_rpki[['Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

# %%
manrs_transit_rpki
# Out:
# rpki_status  asn_id  Invalid  Invalid,more-specific  NotFound   Valid  \
# 0               101        0                      0       179       0
# 1               137        0                      0        21      24
# 2               174        2                      0    303396  154378
# 3               237        0                      0       176      13
# 4               271        0                      0       104       0
# ..              ...      ...                    ...       ...     ...
# 447          328073        0                      0         3       0
# 448          328271        0                      0         2       0
# 449          328594        0                      0        42       0
# 450          328748        0                      0         7       1
# 451          396450        0                      0         3       0
#
# rpki_status  rpki_percent  totalPO  valid_percent
# 0                0.000000      179       0.000000
# ...

# %%
plt.plot(np.sort(manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(manrs_transit_rpki['valid_percent'])), label='MANRS')
#plt.plot(np.sort(sibling_non_manrs_transit_rpki['valid_percent'].dropna()), np.linspace(0,1,len(sibling_non_manrs_transit_rpki['valid_percent'].dropna())), label='MANRS sibling')
plt.plot(np.sort(non_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(non_manrs_transit_rpki['valid_percent'])), label='non-MANRS')
plt.xlabel('Percent of propagated prefixes with valid RPKI status')
plt.ylabel('CDF')
plt.legend()
plt.grid()

# %% [raw]
# small_manrs_transit_rpki['valid_percent'] = (small_manrs_transit_rpki['Valid']/small_manrs_transit_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
# small_non_manrs_transit_rpki['valid_percent'] = (small_non_manrs_transit_rpki['Valid']/small_non_manrs_transit_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
# #small_sibling_non_manrs_transit_rpki['valid_percent'] = (small_sibling_non_manrs_transit_rpki['Valid']/small_sibling_non_manrs_transit_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
#
# medium_manrs_transit_rpki['valid_percent'] = (medium_manrs_transit_rpki['Valid']/medium_manrs_transit_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
# medium_non_manrs_transit_rpki['valid_percent'] = (medium_non_manrs_transit_rpki['Valid']/medium_non_manrs_transit_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
# #medium_sibling_non_manrs_transit_rpki['valid_percent'] = (medium_sibling_non_manrs_transit_rpki['Valid']/medium_sibling_non_manrs_transit_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
#
# large_manrs_transit_rpki['valid_percent'] = (large_manrs_transit_rpki['Valid']/large_manrs_transit_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
# large_non_manrs_transit_rpki['valid_percent'] = (large_non_manrs_transit_rpki['Valid']/large_non_manrs_transit_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
# #large_sibling_non_manrs_transit_rpki['valid_percent'] = (large_sibling_non_manrs_transit_rpki['Valid']/large_sibling_non_manrs_transit_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

# %%
small_non_manrs_transit_rpki.sort_values('Valid', ascending=False)
# Out:
# rpki_status  asn_id  Invalid  Invalid,more-specific  NotFound  Valid  \
# 7144          64049        8                      1      2323   2333
# 4728          41689        0                      0       111    924
# 983            9116        0                      0       275    750
# 4443          39134        0                      0       120    462
# 1075           9744        0                      0        32    420
# ...             ...      ...                    ...       ...    ...
# 4885          42840        0                      0         1      0
# 4882          42830        0                      0         4      0
# 4879          42787        0                      0         2      0
# 4878          42786        0                      0         1      0
# 6085          52748        0                      0         3      0
#
# rpki_status  rpki_percent  totalPO  valid_percent
# 7144            50.203644     4665       0.384287
# ...

# %%
large_manrs_transit_rpki
# Out:
# rpki_status  asn_id  Invalid  Invalid,more-specific  NotFound   Valid  \
# 2               174        2                      0    303396  154378
# 16             1221        0                      0      1093    1582
# 18             1299       25                      0    336722  152937
# 27             2497        1                      0      4781     626
# 28             2516        1                      2      2368     310
# 34             2914        4                      0    149875   84073
# 40             3356        0                      0    345890  156546
# 41             3549        7                      3      4801    2698
# 57             5511        7                      5     12187    7948
# 60             5617        0                      0       379     237
# 62             6461      528                    417     49922   33666
# 64             7015        0                      2       221      40
# ...

# %%
#plt.figure(figsize=(8,6))
plt.plot(np.sort(small_manrs_transit_rpki['valid_percent'].dropna()), np.linspace(0,1,len(small_manrs_transit_rpki['valid_percent'].dropna())), label='small MANRS', linestyle='-')
plt.plot(np.sort(small_non_manrs_transit_rpki['valid_percent'].dropna()), np.linspace(0,1,len(small_non_manrs_transit_rpki['valid_percent'].dropna())), label='small non-MANRS', linestyle='-')
plt.plot(np.sort(medium_manrs_transit_rpki['valid_percent'].dropna()), np.linspace(0,1,len(medium_manrs_transit_rpki['valid_percent'].dropna())), label='medium MANRS', linestyle='--')
plt.plot(np.sort(medium_non_manrs_transit_rpki['valid_percent'].dropna()), np.linspace(0,1,len(medium_non_manrs_transit_rpki['valid_percent'].dropna())), label='medium non-MANRS', linestyle='--')
plt.plot(np.sort(large_manrs_transit_rpki['valid_percent'].dropna()), np.linspace(0,1,len(large_manrs_transit_rpki['valid_percent'].dropna())), label='large MANRS', linestyle='-.')
plt.plot(np.sort(large_non_manrs_transit_rpki['valid_percent'].dropna()), np.linspace(0,1,len(large_non_manrs_transit_rpki['valid_percent'].dropna())), label='large non-MANRS', linestyle='-.')
plt.xlabel('Percent of propagated prefixes with invalid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(-0.5, 5)
#plt.legend(loc=2)
plt.grid()
plt.savefig('manrstransitrpkiinvalid.eps', bbox_inches='tight')

# %%
large_manrs_transit_rpki.describe()
# Out:
# rpki_status        asn_id     Invalid  Invalid,more-specific       NotFound  \
# count           24.000000   24.000000              24.000000      24.000000
# mean         13039.583333   25.583333              18.333333   51963.708333
# std          13726.059028  107.349861              84.938170  111475.817381
# min            174.000000    0.000000               0.000000     187.000000
# 25%           3245.500000    0.000000               0.000000     702.750000
# 50%           7617.500000    0.500000               0.000000    2025.500000
# 75%          17580.000000    2.500000               2.000000   13747.750000
# max          53062.000000  528.000000             417.000000  345890.000000
#
# rpki_status          Valid  rpki_percent        totalPO  valid_percent
# count            24.000000     24.000000      24.000000      24.000000
# mean          25791.208333     29.341016   77798.833333       0.155659
# std           52909.921619     13.405791  164233.233469       0.291848
# ...

# %%
large_manrs_transit_rpki['valid_percent'].value_counts()
# Out:
# 0.000000    11
# 0.000437     1
# 0.005105     1
# 0.018491     1
# 0.111899     1
# 0.001710     1
# 0.133174     1
# 0.059562     1
# 1.117907     1
# 0.760456     1
# 0.291121     1
# 0.496378     1
# 0.177778     1
# 0.561798     1
# Name: valid_percent, dtype: int64

# %%
11/24\%
# Out:
# 0.4583333333333333

# %%
large_manrs_transit_rpki[large_manrs_transit_rpki.valid_percent > 0]
# Out:
# rpki_status  asn_id  Invalid  Invalid,more-specific  NotFound   Valid  \
# 2               174        2                      0    303396  154378
# 18             1299       25                      0    336722  152937
# 27             2497        1                      0      4781     626
# 28             2516        1                      2      2368     310
# 34             2914        4                      0    149875   84073
# 41             3549        7                      3      4801    2698
# 57             5511        7                      5     12187    7948
# 62             6461      528                    417     49922   33666
# 64             7015        0                      2       221      40
# 96            10796        2                      0       570     115
# 144           16735       35                      2      6339    1078
# 154           20473        1                      1       543     580
# ...

# %%
large_non_manrs_transit_rpki.describe()
# Out:
# rpki_status         asn_id     Invalid  Invalid,more-specific       NotFound  \
# count            86.000000   86.000000              86.000000      86.000000
# mean          19759.593023   25.976744              21.151163    6629.523256
# std           36778.785116  102.027791             144.185217   18406.898790
# min             209.000000    0.000000               0.000000      46.000000
# 25%            4666.500000    0.000000               0.000000     504.750000
# 50%            8288.500000    1.000000               0.000000    1531.000000
# 75%           20794.000000    9.750000               2.000000    5047.250000
# max          262589.000000  884.000000            1324.000000  145820.000000
#
# rpki_status         Valid  rpki_percent        totalPO  valid_percent
# count           86.000000     86.000000      86.000000      86.000000
# mean          3796.116279     33.645121   10472.767442       0.402784
# ...

# %%
31/86
# Out:
# 0.36046511627906974

# %%
large_non_manrs_transit_rpki['valid_percent'].value_counts()
# Out:
# 0.000000    31
# 0.047755     1
# 0.275009     1
# 0.110375     1
# 0.816803     1
# 1.469534     1
# 0.540176     1
# 0.059737     1
# 0.236787     1
# 0.386954     1
# 0.481169     1
# 0.204499     1
# 0.184298     1
# 0.017200     1
# 0.311850     1
# 0.104987     1
# 0.143781     1
# 0.097135     1
# 0.011265     1
# 0.146413     1
# 0.485437     1
# 2.348337     1
# 0.874525     1
# 6.410256     1
# 0.330579     1
# 0.490597     1
# 0.202020     1
# 0.184388     1
# 0.104239     1
# 0.706215     1
# 0.577597     1
# 0.135513     1
# 0.729262     1
# 0.532801     1
# 0.587084     1
# 0.069603     1
# 1.954772     1
# 0.009043     1
# 0.549738     1
# 0.020908     1
# 0.049562     1
# 0.304067     1
# 0.231538     1
# 0.035727     1
# 0.063613     1
# 0.403907     1
# 5.130827     1
# 0.013567     1
# 0.045390     1
# 0.032675     1
# 0.058038     1
# 0.064185     1
# 1.076487     1
# 1.344344     1
# 0.312500     1
# 2.524320     1
# Name: valid_percent, dtype: int64

# %%
4072/4405
# Out:
# 0.9244040862656072

# %%
large_non_manrs_transit_rpki[large_non_manrs_transit_rpki.valid_percent == 100]
# Out:
# Empty DataFrame
# Columns: [asn_id, Invalid, Invalid,more-specific, NotFound, Valid, rpki_percent, totalPO, valid_percent]
# Index: []

# %%
plt.plot(np.sort(small_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))+0.1, np.linspace(0,1,len(small_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))), label='small MANRS', linestyle='-')
plt.plot(np.sort(small_non_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))+0.1, np.linspace(0,1,len(small_non_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))), label='small non-MANRS', linestyle='-')
plt.plot(np.sort(medium_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))+0.1, np.linspace(0,1,len(medium_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))), label='medium MANRS', linestyle='--')
plt.plot(np.sort(medium_non_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))+0.1, np.linspace(0,1,len(medium_non_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))), label='medium non-MANRS', linestyle='--')
plt.plot(np.sort(large_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))+0.1, np.linspace(0,1,len(large_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))), label='large MANRS', linestyle='-.')
plt.plot(np.sort(large_non_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))+0.1, np.linspace(0,1,len(large_non_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1))), label='large non-MANRS', linestyle='-.')
plt.xlabel('# propagated prefixes with invalid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xscale('log')
#plt.legend(loc=2)
plt.grid()

# %%
plt.scatter(large_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1)+0.1, large_manrs_transit_rpki['Valid']+0.1, label='large MANRS')
plt.scatter(large_non_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1)+0.1, large_non_manrs_transit_rpki['Valid']+0.1, label='large non-MANRS')
plt.xlabel('RPKI Invalid')
plt.ylabel('RPKI Valid')
plt.yscale('log')
plt.xscale('log')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size':11})
plt.grid()
# plt.savefig('manrs1compliantscatter.eps', bbox_inches='tight')

# %%
plt.scatter(medium_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1)+0.1, medium_manrs_transit_rpki['Valid']+0.1, label='medium MANRS')
plt.scatter(medium_non_manrs_transit_rpki[['Invalid','Invalid,more-specific']].sum(axis=1)+0.1, medium_non_manrs_transit_rpki['Valid']+0.1, label='medium non-MANRS')
plt.xlabel('RPKI Invalid')
plt.ylabel('RPKI Valid')
plt.yscale('log')
plt.xscale('log')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size':11})
plt.grid()

# %%
large_non_manrs_transit_rpki['valid_percent'].max()
# Out:
# 6.41025641025641

# %%
large_manrs_transit_rpki['valid_percent'].max()
# Out:
# 1.1179066163510107

# %% [markdown]
# #### all sizes, customer relationship

# %%
sample = small_manrs_transit_rpki[small_manrs_transit_rpki.relationship == 'customer']
nsample = small_non_manrs_transit_rpki[small_non_manrs_transit_rpki.relationship == 'customer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='customer of small MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='customer small non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_28912/2321826181.py in <module>
# ----> 1 sample = small_manrs_transit_rpki[small_manrs_transit_rpki.relationship == 'customer']
#       2 nsample = small_non_manrs_transit_rpki[small_non_manrs_transit_rpki.relationship == 'customer']
#       3 plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='customer of small MANRS ({})'.format(len(sample)), linestyle='-')
#       4 plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='customer small non-MANRS ({})'.format(len(nsample)), linestyle='-')
#       5 plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# ...

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 409 32116

# %%
sample = medium_manrs_transit_rpki[medium_manrs_transit_rpki.relationship == 'customer']
nsample = medium_non_manrs_transit_rpki[medium_non_manrs_transit_rpki.relationship == 'customer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='customer of medium MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='customer medium non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 49622 401689

# %%
sample = large_manrs_transit_rpki[large_manrs_transit_rpki.relationship == 'customer']
nsample = large_non_manrs_transit_rpki[large_non_manrs_transit_rpki.relationship == 'customer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='customer of large MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='customer of large non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 528370 394290

# %% [markdown]
# #### all sizes, peers

# %%
sample = small_manrs_transit_rpki[small_manrs_transit_rpki.relationship == 'peer']
nsample = small_non_manrs_transit_rpki[small_non_manrs_transit_rpki.relationship == 'peer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='peer of small MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='peer of small non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 27 4023

# %%
sample = medium_manrs_transit_rpki[medium_manrs_transit_rpki.relationship == 'peer']
nsample = medium_non_manrs_transit_rpki[medium_non_manrs_transit_rpki.relationship == 'peer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='peer of medium MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='peer of medium non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 173 2141

# %%
sample = large_manrs_transit_rpki[large_manrs_transit_rpki.relationship == 'peer']
nsample = large_non_manrs_transit_rpki[large_non_manrs_transit_rpki.relationship == 'peer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='peer of large MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='peer of large non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 52543 70591

# %% [markdown]
# #### all sizes, no relationship

# %%
sample = small_manrs_transit_rpki[small_manrs_transit_rpki.relationship == 'norel']
nsample = small_non_manrs_transit_rpki[small_non_manrs_transit_rpki.relationship == 'norel']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='norel of small MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='norel of small non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 168 18227

# %%
sample = medium_manrs_transit_rpki[medium_manrs_transit_rpki.relationship == 'norel']
nsample = medium_non_manrs_transit_rpki[medium_non_manrs_transit_rpki.relationship == 'norel']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='norel of medium MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='norel of medium non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 24994 188938

# %%
sample = large_manrs_transit_rpki[large_manrs_transit_rpki.relationship == 'norel']
nsample = large_non_manrs_transit_rpki[large_non_manrs_transit_rpki.relationship == 'norel']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='norel of large MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='norel of large non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 1286259 435769

# %% [markdown]
# #### small networks, all rel

# %%
sample1 = small_manrs_transit_rpki[small_manrs_transit_rpki.relationship == 'customer']
sample2 = small_manrs_transit_rpki[small_manrs_transit_rpki.relationship == 'peer']
sample3 = small_manrs_transit_rpki[small_manrs_transit_rpki.relationship == 'norel']
plt.plot(np.sort(sample1['valid_percent']), np.linspace(0,1,len(sample1)), label='customer of small MANRS ({})'.format(len(sample1)))
plt.plot(np.sort(sample2['valid_percent']), np.linspace(0,1,len(sample2)), label='peer of small MANRS ({})'.format(len(sample2)))
plt.plot(np.sort(sample3['valid_percent']), np.linspace(0,1,len(sample3)), label='norel of small MANRS ({})'.format(len(sample3)))
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample1['totalPO'].sum(), sample2['totalPO'].sum(), sample3['totalPO'].sum())
# Out:
# total PO propagated: 409 27 168

# %% [markdown]
# #### medium network, all rel

# %%
sample1 = medium_manrs_transit_rpki[medium_manrs_transit_rpki.relationship == 'customer']
sample2 = medium_manrs_transit_rpki[medium_manrs_transit_rpki.relationship == 'peer']
sample3 = medium_manrs_transit_rpki[medium_manrs_transit_rpki.relationship == 'norel']
plt.plot(np.sort(sample1['valid_percent']), np.linspace(0,1,len(sample1)), label='customer of medium MANRS ({})'.format(len(sample1)))
plt.plot(np.sort(sample2['valid_percent']), np.linspace(0,1,len(sample2)), label='peer of medium MANRS ({})'.format(len(sample2)))
plt.plot(np.sort(sample3['valid_percent']), np.linspace(0,1,len(sample3)), label='norel of medium MANRS ({})'.format(len(sample3)))
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample1['totalPO'].sum(), sample2['totalPO'].sum(), sample3['totalPO'].sum())
# Out:
# total PO propagated: 49622 173 24994

# %% [markdown]
# #### large networks, all rel

# %%
sample1 = large_manrs_transit_rpki[large_manrs_transit_rpki.relationship == 'customer']
sample2 = large_manrs_transit_rpki[large_manrs_transit_rpki.relationship == 'peer']
sample3 = large_manrs_transit_rpki[large_manrs_transit_rpki.relationship == 'norel']
plt.plot(np.sort(sample1['valid_percent']), np.linspace(0,1,len(sample1)), label='customer of large MANRS ({})'.format(len(sample1)))
plt.plot(np.sort(sample2['valid_percent']), np.linspace(0,1,len(sample2)), label='peer of large MANRS ({})'.format(len(sample2)))
plt.plot(np.sort(sample3['valid_percent']), np.linspace(0,1,len(sample3)), label='norel of large MANRS ({})'.format(len(sample3)))
plt.xlabel('Percent of propagated prefixes with valid RPKI status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample1['totalPO'].sum(), sample2['totalPO'].sum(), sample3['totalPO'].sum())
# Out:
# total PO propagated: 528370 52543 1286259

# %%
large_manrs_transit['originasn_id'].nunique()
# Out:
# 65899

# %%
small_manrs_transit_rpki[small_manrs_transit_rpki.relationship == 'peer']
# Out:
# rpki_status  asn_id relationship  Invalid  Invalid,more-specific  NotFound  \
# 264           17359         peer        0                      0         0
# 456           39650         peer        0                      0         0
# 537           53231         peer        0                      0         3
# 614          209638         peer        0                      0         0
#
# rpki_status  Valid  rpki_percent  valid_percent
# 264              1         100.0          100.0
# 456             19         100.0          100.0
# 537              0           0.0            0.0
# 614              4         100.0          100.0

# %%
small_non_manrs_transit_rpki[small_non_manrs_transit_rpki.relationship == 'peer']
# Out:
# rpki_status  asn_id relationship  Invalid  Invalid,more-specific  NotFound  \
# 46              367         peer        0                      0      2443
# 56              575         peer        0                      0       322
# 140            1555         peer        0                      0        91
# 147            1733         peer        0                      0       207
# 228            2629         peer        0                      0         3
# ...             ...          ...      ...                    ...       ...
# 13100        269139         peer        0                      0         1
# 13375        272213         peer        0                      0         0
# 13394        272501         peer        0                      0         1
# 13410        327738         peer        0                      0         1
# 13442        327981         peer        0                      0         1
#
# rpki_status  Valid  rpki_percent  valid_percent
# ...

# %% [raw]
# plt.figure(figsize=(8,6))
# plt.plot(np.sort(small_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(small_manrs_transit_rpki)), label='small MANRS', linestyle='-')
# plt.plot(np.sort(small_sibling_non_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(small_sibling_non_manrs_transit_rpki)), label='small sibling MANRS', linestyle='-')
# plt.plot(np.sort(medium_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(medium_manrs_transit_rpki)), label='medium MANRS', linestyle='--')
# plt.plot(np.sort(medium_sibling_non_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(medium_sibling_non_manrs_transit_rpki)), label='medium sibling MANRS', linestyle='--')
# plt.plot(np.sort(large_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(large_manrs_transit_rpki)), label='large MANRS', linestyle='-.')
# plt.plot(np.sort(large_sibling_non_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(large_sibling_non_manrs_transit_rpki)), label='large sibling MANRS', linestyle='-.')
# plt.xlabel('Percent of propagated prefixes with valid RPKI status')
# plt.ylabel('CDF')
# #plt.xlim(80, 105)
# plt.legend()
# plt.grid()

# %% [raw]
# plt.figure(figsize=(8,6))
# plt.plot(np.sort(small_non_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(small_non_manrs_transit_rpki)), label='small non MANRS', linestyle='-')
# plt.plot(np.sort(small_sibling_non_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(small_sibling_non_manrs_transit_rpki)), label='small sibling MANRS', linestyle='-')
# plt.plot(np.sort(medium_non_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(medium_non_manrs_transit_rpki)), label='medium non MANRS', linestyle='--')
# plt.plot(np.sort(medium_sibling_non_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(medium_sibling_non_manrs_transit_rpki)), label='medium sibling MANRS', linestyle='--')
# plt.plot(np.sort(large_non_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(large_non_manrs_transit_rpki)), label='large non MANRS', linestyle='-.')
# plt.plot(np.sort(large_sibling_non_manrs_transit_rpki['valid_percent']), np.linspace(0,1,len(large_sibling_non_manrs_transit_rpki)), label='large sibling MANRS', linestyle='-.')
# plt.xlabel('Percent of propagated prefixes with valid RPKI status')
# plt.ylabel('CDF')
# #plt.xlim(80, 105)
# plt.legend()
# plt.grid()

# %% [markdown]
# ### How many RPKI valids, invalids do each type of networks propagate?

# %% [markdown]
# #### small networks

# %%
plt.scatter(small_manrs_transit_rpki['Invalid'], small_manrs_transit_rpki['Valid'])
plt.xlabel('RPKI Invalid ASN')
plt.ylabel('RPKI Valid')
plt.grid()

# %% [markdown]
# who?? 19115 charter; Forhosting NL

# %%
small_manrs_transit_rpki[small_manrs_transit_rpki.Invalid > 0]
# Out:
# rpki_status  asn_id  Invalid  Invalid,more-specific  NotFound  Valid  \
# 261           36914        1                      0         1      0
#
# rpki_status  rpki_percent  valid_percent
# 261                  50.0            0.0

# %%
manrs_transit[manrs_transit.asn_id.isin([19115, 142419]) & (manrs_transit.rpki_status == 'Invalid')]
# Out:
# Empty DataFrame
# Columns: [id, timebin, prefix, hege, af, visibility, rpki_status, irr_status, delegated_prefix_status, delegated_asn_status, descr, moas, asn_id, country_id, originasn_id, nettype]
# Index: []

# %%
plt.scatter(small_manrs_transit_rpki['Invalid,more-specific'], small_manrs_transit_rpki['Valid'])
plt.xlabel('RPKI Invalid,more-specific')
plt.ylabel('RPKI Valid')
plt.grid()

# %%
plt.scatter(small_manrs_transit_rpki['NotFound'], small_manrs_transit_rpki['Valid'])
plt.xlabel('RPKI NotFound')
plt.ylabel('RPKI Valid')
# plt.xscale('log')
# plt.yscale('log')
plt.grid()

# %% [markdown]
# #### medium networks

# %%
plt.scatter(medium_manrs_transit_rpki['Invalid'], medium_manrs_transit_rpki['Valid'])
plt.xlabel('RPKI Invalid ASN')
plt.ylabel('RPKI Valid')
plt.grid()

# %%
med_invalid_ASN = medium_manrs_transit_rpki[medium_manrs_transit_rpki.Invalid > 0]['asn_id']
for i in med_invalid_ASN:
    try:
        print(i, manrs_org[int(i)])
    except:
        print(i)
# Out:
# 10021 Colt Technology Services
# 16509 Amazon Web Services
# 20940 Akamai Technologies
# 23688 Link3 Technologies Ltd.
# 33659 Comcast
# 52468 Ufinet

# %%
manrs_transit[manrs_transit.asn_id.isin(med_invalid_ASN) & (manrs_transit.rpki_status == 'Invalid')]
# Out:
#                  id                 timebin            prefix      hege  af  \
# 705730   1415683351  2022-05-01 00:00:00+00   200.60.190.0/24  0.360544   4
# 705744   1415683337  2022-05-01 00:00:00+00   200.60.136.0/23  0.360544   4
# 1525613  1414863520  2022-05-01 00:00:00+00    154.215.1.0/24  0.115646   4
# 1539864  1414849266  2022-05-01 00:00:00+00  130.156.192.0/20  0.346939   4
# 1968948  1414420163  2022-05-01 00:00:00+00    103.9.104.0/24  0.639456   4
# 1969760  1414419749  2022-05-01 00:00:00+00    170.82.39.0/24  0.646259   4
# 2120580  1414267989  2022-05-01 00:00:00+00    103.9.104.0/23  0.639456   4
# 3484956  1412903885  2022-05-01 00:00:00+00   200.60.136.0/24  0.360544   4
# 3486203  1412903306  2022-05-01 00:00:00+00   158.51.108.0/24  0.489796   4
# 3494986  1412893665  2022-05-01 00:00:00+00    103.9.105.0/24  0.639456   4
#
#          visibility rpki_status irr_status delegated_prefix_status  \
# ...

# %%
plt.scatter(medium_manrs_transit_rpki['Invalid,more-specific'], medium_manrs_transit_rpki['Valid'])
plt.xlabel('RPKI Invalid,more-specific')
plt.ylabel('RPKI Valid')
plt.grid()

# %%
med_invalid_len = medium_manrs_transit_rpki[medium_manrs_transit_rpki['Invalid,more-specific'] > 0]['asn_id']
for i in med_invalid_len:
    try:
        print(i, manrs_org[int(i)])
    except:
        print(i)
# Out:
# 23674 Nayatel Pvt. Ltd
# 28294 Univox
# 48362 Stadtwerke Feldkirch

# %%
manrs_transit[manrs_transit.asn_id.isin(med_invalid_len) & (manrs_transit.rpki_status == 'Invalid,more-specific')]
# Out:
#                  id                 timebin            prefix      hege  af  \
# 718348   1415670555  2022-05-01 00:00:00+00    92.249.22.0/24  0.034014   4
# 1526355  1414862791  2022-05-01 00:00:00+00    101.50.84.0/22  0.387755   4
# 1549420  1414839426  2022-05-01 00:00:00+00  179.107.208.0/21  0.435374   4
# 1963005  1414426153  2022-05-01 00:00:00+00    92.249.20.0/24  0.034014   4
#
#          visibility            rpki_status             irr_status  \
# 718348    11.475410  Invalid,more-specific  Invalid,more-specific
# 1526355   36.612022  Invalid,more-specific  Invalid,more-specific
# 1549420   40.983607  Invalid,more-specific                  Valid
# 1963005   11.475410  Invalid,more-specific  Invalid,more-specific
#
#         delegated_prefix_status delegated_asn_status  \
# 718348                 assigned             assigned
# 1526355                assigned             assigned
# 1549420                assigned             assigned
# ...

# %%
plt.scatter(medium_manrs_transit_rpki['NotFound'], medium_manrs_transit_rpki['Valid'])
plt.xlabel('RPKI NotFound')
plt.ylabel('RPKI Valid')
# plt.xscale('log')
# plt.yscale('log')
plt.grid()

# %% [markdown]
# #### large networks

# %%
plt.scatter(large_manrs_transit_rpki['Invalid'], large_manrs_transit_rpki['Valid'])
plt.xlabel('RPKI Invalid')
plt.ylabel('RPKI Valid')
# plt.xscale('log')
# plt.yscale('log')
plt.grid()

# %%
large_invalid_ASN = large_manrs_transit_rpki[large_manrs_transit_rpki.Invalid > 0]['asn_id']
for i in large_invalid_ASN:
    try:
        print(i, manrs_org[int(i)])
    except:
        print(i)
# Out:
# 174 Cogent Communications Inc.
# 3356 CenturyLink
# 3549 CenturyLink
# 13335 Cloudflare
# 20115 Charter Communications

# %%
manrs_transit[manrs_transit.asn_id.isin(large_invalid_ASN) & (manrs_transit.rpki_status == 'Invalid')]
# Out:
#                  id                 timebin            prefix      hege  af  \
# 699120   1415689926  2022-05-01 00:00:00+00  178.171.100.0/24  0.632653   4
# 717770   1415671250  2022-05-01 00:00:00+00   212.69.135.0/24  0.061224   4
# 719522   1415669945  2022-05-01 00:00:00+00   45.172.187.0/24  0.210884   4
# 1545909  1414843588  2022-05-01 00:00:00+00    45.84.242.0/24  0.632653   4
# 1557276  1414831811  2022-05-01 00:00:00+00   216.173.83.0/24  0.061224   4
# 2114870  1414274639  2022-05-01 00:00:00+00    98.154.77.0/24  0.006803   4
# 2121627  1414268231  2022-05-01 00:00:00+00    85.239.55.0/24  0.700680   4
# 2121642  1414268216  2022-05-01 00:00:00+00    45.84.243.0/24  0.632653   4
# 4346576  1412042289  2022-05-01 00:00:00+00   103.21.244.0/24  0.687075   4
# 4537577  1411851404  2022-05-01 00:00:00+00     47.19.10.0/24  0.646259   4
# 5189951  1411199558  2022-05-01 00:00:00+00   173.241.94.0/24  0.646259   4
# ...

# %%
plt.scatter(large_manrs_transit_rpki['Invalid,more-specific'], large_manrs_transit_rpki['Valid'])
plt.xlabel('RPKI Invalid,more-specific')
plt.ylabel('RPKI Valid')
# plt.xscale('log')
# plt.yscale('log')
plt.grid()

# %%
large_non_manrs_transit_rpki
# Out:
# rpki_status  originasn_id  Invalid  Invalid,more-specific  NotFound  Valid  \
# 106                   209        0                      0      2463     58
# 235                   577        0                      0       675      0
# 269                   701        0                      0      1003    122
# 270                   702        0                      0       196      2
# 314                   852        0                      1       450    214
# 391                  1239        1                      0       277   1714
# 398                  1257        0                      0       429     50
# 405                  1273        0                     40       174     48
# 917                  2828        0                      0       112      0
# 936                  2856        1                      0       229    113
# 1028                 3216        0                      0       788      0
# ...

# %%
large_invalid_len = large_manrs_transit_rpki[large_manrs_transit_rpki['Invalid,more-specific'] > 0]['asn_id']
for i in large_invalid_len:
    try:
        print(i, manrs_org[int(i)])
    except:
        print(i)
# Out:
# 13335 Cloudflare

# %%
manrs_transit[manrs_transit.asn_id.isin(large_invalid_len) & (manrs_transit.rpki_status == 'Invalid,more-specific')]
# Out:
#                  id                 timebin          prefix      hege  af  \
# 1963043  1414426058  2022-05-01 00:00:00+00  172.68.83.0/24  0.129252   4
#
#          visibility            rpki_status             irr_status  \
# 1963043   18.579235  Invalid,more-specific  Invalid,more-specific
#
#         delegated_prefix_status delegated_asn_status  \
# 1963043                assigned             assigned
#
#                                                      descr moas  asn_id  \
# 1963043  101 Townsend Street, San Francisco, California...    f   13335
#
#         country_id  originasn_id nettype
# 1963043         US         13335     CDN

# %%
plt.scatter(large_manrs_transit_rpki['NotFound'], large_manrs_transit_rpki['Valid'])
plt.xlabel('RPKI NotFound')
plt.ylabel('RPKI Valid')
# plt.xscale('log')
# plt.yscale('log')
plt.grid()

# %%
plt.boxplot(small_manrs_transit_rpki['rpki_percent'])
plt.boxplot(small_non_manrs_transit_rpki['rpki_percent'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2becb9e790>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f2becb9eeb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2becb9e400>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2becb94610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2becb949a0>],
#  'means': []}

# %% [markdown]
# ## IRR

# %% [markdown]
# ### Does MANRS networks originate more prefixes with IRR record?

# %%
manrs_transit_irr = manrs_transit.groupby(['asn_id', 'irr_status']).size().unstack(fill_value=0).reset_index()
manrs_transit_irr['irr_percent'] = (1-manrs_transit_irr['NotFound']/manrs_transit_irr[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1))*100
manrs_transit_irr['totalPO'] = manrs_transit_irr[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1)

# %%
non_manrs_transit_irr = non_manrs_transit.groupby(['asn_id', 'irr_status']).size().unstack(fill_value=0).reset_index()
non_manrs_transit_irr['irr_percent'] = (1-non_manrs_transit_irr['NotFound']/non_manrs_transit_irr[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1))*100
non_manrs_transit_irr['totalPO'] = non_manrs_transit_irr[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1)

# %%
plt.plot(np.sort(manrs_transit_irr['irr_percent']), np.linspace(0,1,len(manrs_transit_irr)), label='MANRS')
plt.plot(np.sort(non_manrs_transit_irr['irr_percent']), np.linspace(0,1,len(non_manrs_transit_irr)), label='non-MANRS')
plt.xlabel('Percent of propagated prefixes with irr records')
plt.ylabel('CDF')
plt.legend()
plt.grid()

# %%
small_manrs_transit_irr = manrs_transit_irr[manrs_transit_irr.asn_id.isin(small)]
medium_manrs_transit_irr = manrs_transit_irr[manrs_transit_irr.asn_id.isin(medium)]
large_manrs_transit_irr = manrs_transit_irr[manrs_transit_irr.asn_id.isin(large)]
small_non_manrs_transit_irr = non_manrs_transit_irr[non_manrs_transit_irr.asn_id.isin(small)]
medium_non_manrs_transit_irr = non_manrs_transit_irr[non_manrs_transit_irr.asn_id.isin(medium)]
large_non_manrs_transit_irr = non_manrs_transit_irr[non_manrs_transit_irr.asn_id.isin(large)]

# %%
plt.figure(figsize=(8,6))
plt.plot(np.sort(small_manrs_transit_irr['irr_percent']), np.linspace(0,1,len(small_manrs_transit_irr)), label='small MANRS', linestyle='-')
plt.plot(np.sort(small_non_manrs_transit_irr['irr_percent']), np.linspace(0,1,len(small_non_manrs_transit_irr)), label='small non-MANRS', linestyle='-')
plt.plot(np.sort(medium_manrs_transit_irr['irr_percent']), np.linspace(0,1,len(medium_manrs_transit_irr)), label='medium MANRS', linestyle='--')
plt.plot(np.sort(medium_non_manrs_transit_irr['irr_percent']), np.linspace(0,1,len(medium_non_manrs_transit_irr)), label='medium non-MANRS', linestyle='--')
plt.plot(np.sort(large_manrs_transit_irr['irr_percent']), np.linspace(0,1,len(large_manrs_transit_irr)), label='large MANRS', linestyle='-.')
plt.plot(np.sort(large_non_manrs_transit_irr['irr_percent']), np.linspace(0,1,len(large_non_manrs_transit_irr)), label='large non-MANRS', linestyle='-.')
plt.xlabel('Percent of propagated prefixes with irr records')
plt.ylabel('CDF')
plt.legend()
plt.grid()

# %% [markdown]
# ### Does MANRS originate more irr valids than non_MANRS?

# %%
manrs_transit_irr['valid_percent'] = (manrs_transit_irr[['Invalid']].sum(axis=1)/manrs_transit_irr[['Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
non_manrs_transit_irr['valid_percent'] = (non_manrs_transit_irr[['Invalid']].sum(axis=1)/non_manrs_transit_irr[['Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

# %%
plt.plot(np.sort(manrs_transit_irr['valid_percent'].dropna()), np.linspace(0,1,len(manrs_transit_irr['valid_percent'].dropna())), label='MANRS')
plt.plot(np.sort(non_manrs_transit_irr['valid_percent'].dropna()), np.linspace(0,1,len(non_manrs_transit_irr['valid_percent'].dropna())), label='non-MANRS')
plt.xlabel('Percent of propagated prefixes with valid irr status')
plt.ylabel('CDF')
plt.legend()
plt.grid()

# %%
small_manrs_transit_irr['valid_percent'] = (small_manrs_transit_irr['Valid']/small_manrs_transit_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
small_non_manrs_transit_irr['valid_percent'] = (small_non_manrs_transit_irr['Valid']/small_non_manrs_transit_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

medium_manrs_transit_irr['valid_percent'] = (medium_manrs_transit_irr['Valid']/medium_manrs_transit_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
medium_non_manrs_transit_irr['valid_percent'] = (medium_non_manrs_transit_irr['Valid']/medium_non_manrs_transit_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

large_manrs_transit_irr['valid_percent'] = (large_manrs_transit_irr['Valid']/large_manrs_transit_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
large_non_manrs_transit_irr['valid_percent'] = (large_non_manrs_transit_irr['Valid']/large_non_manrs_transit_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
# Out:
# /home/c4du/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
print(len(small_manrs), len(medium_manrs), len(large_manrs))
# Out:
# 451 319 24

# %%
print(len(small_non_manrs), len(medium_non_manrs), len(large_non_manrs))
# Out:
# 68383 4489 86

# %%
#plt.figure(figsize=(8,6))
plt.plot(np.sort(small_manrs_transit_irr['valid_percent']), np.linspace(0,1,len(small_manrs_transit_irr)), label='small MANRS (449)', linestyle='-')
plt.plot(np.sort(small_non_manrs_transit_irr['valid_percent']), np.linspace(0,1,len(small_non_manrs_transit_irr)), label='small non-MANRS (68,385)', linestyle='-')
plt.plot(np.sort(medium_manrs_transit_irr['valid_percent']), np.linspace(0,1,len(medium_manrs_transit_irr)), label='medium MANRS (315)', linestyle='--')
plt.plot(np.sort(medium_non_manrs_transit_irr['valid_percent']), np.linspace(0,1,len(medium_non_manrs_transit_irr)), label='medium non-MANRS (4,493)', linestyle='--')
plt.plot(np.sort(large_manrs_transit_irr['valid_percent']), np.linspace(0,1,len(large_manrs_transit_irr)), label='large MANRS (24)', linestyle='-.')
plt.plot(np.sort(large_non_manrs_transit_irr['valid_percent']), np.linspace(0,1,len(large_non_manrs_transit_irr)), label='large non-MANRS (86)', linestyle='-.')
plt.xlabel('Percent of propagated prefixes with invalid IRR status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size':11})
plt.xlim(0,40)
plt.grid()
#plt.savefig('manrstransitirrinvalid.eps', bbox_inches='tight')

# %%
large_manrs_transit_irr.describe()
# Out:
# irr_status        asn_id       Invalid  Invalid,more-specific      NotFound  \
# count          24.000000     24.000000              24.000000     24.000000
# mean        13039.583333   6470.750000           19021.041667   3017.375000
# std         13726.059028  14554.906133           41036.366236   6601.135764
# min           174.000000      7.000000               4.000000      0.000000
# 25%          3245.500000     19.500000              97.500000      3.000000
# 50%          7617.500000     57.500000             292.000000      8.000000
# 75%         17580.000000    625.000000            4666.250000    640.750000
# max         53062.000000  45497.000000          129443.000000  19513.000000
#
# irr_status          Valid  irr_percent        totalPO  valid_percent
# count           24.000000    24.000000      24.000000      24.000000
# mean         49289.666667    97.871676   77798.833333       6.008638
# std         102237.907210     2.472675  164233.233469       6.316928
# ...

# %%
large_manrs_transit_irr.var()
# Out:
# irr_status
# asn_id                   1.884047e+08
# Invalid                  2.118453e+08
# Invalid,more-specific    1.683983e+09
# NotFound                 4.357499e+07
# Valid                    1.045259e+10
# irr_percent              6.114122e+00
# totalPO                  2.697255e+10
# valid_percent            3.990358e+01
# dtype: float64

# %%
large_non_manrs_transit_irr.describe()
# Out:
# irr_status         asn_id       Invalid  Invalid,more-specific     NotFound  \
# count           86.000000     86.000000              86.000000    86.000000
# mean         19759.593023    767.104651            1935.709302   257.441860
# std          36778.785116   2108.273138            5831.589076   690.917337
# min            209.000000      0.000000               0.000000     0.000000
# 25%           4666.500000     12.750000              63.250000     2.000000
# 50%           8288.500000     73.500000             245.000000     6.500000
# 75%          20794.000000    430.750000             981.500000    70.250000
# max         262589.000000  12414.000000           43533.000000  3491.000000
#
# irr_status          Valid  irr_percent        totalPO  valid_percent
# count           86.000000    86.000000      86.000000      86.000000
# mean          7512.511628    97.384913   10472.767442       7.166670
# std          21542.980714     5.696969   29243.027641      11.579236
# ...

# %%
large_non_manrs_transit_irr.var()
# Out:
# irr_status
# asn_id                   1.352679e+09
# Invalid                  4.444816e+06
# Invalid,more-specific    3.400743e+07
# NotFound                 4.773668e+05
# Valid                    4.641000e+08
# irr_percent              3.245545e+01
# totalPO                  8.551547e+08
# valid_percent            1.340787e+02
# dtype: float64

# %%
small_manrs_transit_irr['valid_percent'].value_counts()/len(small_manrs_transit_irr)
# Out:
# 0.000000      0.940678
# 100.000000    0.033898
# 66.666667     0.008475
# 4.761905      0.008475
# 50.000000     0.008475
# Name: valid_percent, dtype: float64

# %%
small_non_manrs_transit_irr['valid_percent'].value_counts()/len(small_non_manrs_transit_irr)
# Out:
# 0.000000      0.854560
# 100.000000    0.063355
# 50.000000     0.011075
# 33.333333     0.004560
# 25.000000     0.003746
#                 ...
# 53.537068     0.000163
# 4.424779      0.000163
# 36.363636     0.000163
# 3.174603      0.000163
# 4.672897      0.000163
# Name: valid_percent, Length: 155, dtype: float64

# %%
medium_manrs_transit_irr['valid_percent'].value_counts()/len(medium_manrs_transit_irr)
# Out:
# 0.000000     0.593548
# 1.351351     0.009677
# 2.197802     0.006452
# 20.000000    0.006452
# 18.750000    0.006452
#                ...
# 3.083700     0.003226
# 5.283019     0.003226
# 0.892857     0.003226
# 1.327945     0.003226
# 5.882353     0.003226
# Name: valid_percent, Length: 116, dtype: float64

# %%
medium_non_manrs_transit_irr['valid_percent'].value_counts()/len(medium_non_manrs_transit_irr)
# Out:
# 0.000000     0.630420
# 25.000000    0.006129
# 33.333333    0.005902
# 20.000000    0.005675
# 12.500000    0.005675
#                ...
# 9.223301     0.000227
# 21.739130    0.000227
# 2.803738     0.000227
# 6.382979     0.000227
# 6.329114     0.000227
# Name: valid_percent, Length: 840, dtype: float64

# %%
plt.plot(np.sort(small_manrs_transit_irr[['Invalid']].sum(axis=1))+0.1, np.linspace(0,1,len(small_manrs_transit_irr[['Invalid']].sum(axis=1))), label='small MANRS', linestyle='-')
plt.plot(np.sort(small_non_manrs_transit_irr[['Invalid']].sum(axis=1))+0.1, np.linspace(0,1,len(small_non_manrs_transit_irr[['Invalid']].sum(axis=1))), label='small non-MANRS', linestyle='-')
plt.plot(np.sort(medium_manrs_transit_irr[['Invalid']].sum(axis=1))+0.1, np.linspace(0,1,len(medium_manrs_transit_irr[['Invalid']].sum(axis=1))), label='medium MANRS', linestyle='--')
plt.plot(np.sort(medium_non_manrs_transit_irr[['Invalid']].sum(axis=1))+0.1, np.linspace(0,1,len(medium_non_manrs_transit_irr[['Invalid']].sum(axis=1))), label='medium non-MANRS', linestyle='--')
plt.plot(np.sort(large_manrs_transit_irr[['Invalid']].sum(axis=1))+0.1, np.linspace(0,1,len(large_manrs_transit_irr[['Invalid']].sum(axis=1))), label='large MANRS', linestyle='-.')
plt.plot(np.sort(large_non_manrs_transit_irr[['Invalid']].sum(axis=1))+0.1, np.linspace(0,1,len(large_non_manrs_transit_irr[['Invalid']].sum(axis=1))), label='large non-MANRS', linestyle='-.')
plt.xlabel('# propagated prefixes with invalid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xscale('log')
#plt.legend(loc=2)
plt.grid()

# %%
manrs_transit_irr
# Out:
# irr_status  asn_id  Invalid  Invalid,more-specific  NotFound   Valid  \
# 0              101        0                      0         0     179
# 1              137        1                      0         0      44
# 2              174    38067                 113801     18967  286941
# 3              237        7                    122         0      60
# 4              271        0                      7         0      97
# ..             ...      ...                    ...       ...     ...
# 447         328073        0                      0         0       3
# 448         328271        1                      0         0       1
# 449         328594        0                     16         0      26
# 450         328748        0                      0         0       8
# 451         396450        0                      3         0       0
#
# irr_status  irr_percent  totalPO  valid_percent
# 0            100.000000      179       0.000000
# ...

# %%
large_manrs_transit_irr['valid_percent'].max()
# Out:
# 24.324324324324326

# %%
large_non_manrs_transit_irr['valid_percent'].max()
# Out:
# 68.36279530811169

# %% [markdown]
# #### all sizes, customer relationship

# %%
sample = small_manrs_transit_irr[small_manrs_transit_irr.relationship == 'customer']
nsample = small_non_manrs_transit_irr[small_non_manrs_transit_irr.relationship == 'customer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='customer of small MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='customer small non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 409 32116

# %%
sample = medium_manrs_transit_irr[medium_manrs_transit_irr.relationship == 'customer']
nsample = medium_non_manrs_transit_irr[medium_non_manrs_transit_irr.relationship == 'customer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='customer of medium MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='customer medium non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 49622 401689

# %%
sample = large_manrs_transit_irr[large_manrs_transit_irr.relationship == 'customer']
nsample = large_non_manrs_transit_irr[large_non_manrs_transit_irr.relationship == 'customer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='customer of large MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='customer of large non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 528370 394290

# %% [markdown]
# #### all sizes, peers

# %%
sample = small_manrs_transit_irr[small_manrs_transit_irr.relationship == 'peer']
nsample = small_non_manrs_transit_irr[small_non_manrs_transit_irr.relationship == 'peer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='peer of small MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='peer of small non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 27 4023

# %%
sample = medium_manrs_transit_irr[medium_manrs_transit_irr.relationship == 'peer']
nsample = medium_non_manrs_transit_irr[medium_non_manrs_transit_irr.relationship == 'peer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='peer of medium MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='peer of medium non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 173 2141

# %%
sample = large_manrs_transit_irr[large_manrs_transit_irr.relationship == 'peer']
nsample = large_non_manrs_transit_irr[large_non_manrs_transit_irr.relationship == 'peer']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='peer of large MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='peer of large non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 52543 70591

# %% [markdown]
# #### all sizes, no relationship

# %%
sample = small_manrs_transit_irr[small_manrs_transit_irr.relationship == 'norel']
nsample = small_non_manrs_transit_irr[small_non_manrs_transit_irr.relationship == 'norel']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='norel of small MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='norel of small non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 168 18227

# %%
sample = medium_manrs_transit_irr[medium_manrs_transit_irr.relationship == 'norel']
nsample = medium_non_manrs_transit_irr[medium_non_manrs_transit_irr.relationship == 'norel']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='norel of medium MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='norel of medium non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 24994 188938

# %%
sample = large_manrs_transit_irr[large_manrs_transit_irr.relationship == 'norel']
nsample = large_non_manrs_transit_irr[large_non_manrs_transit_irr.relationship == 'norel']
plt.plot(np.sort(sample['valid_percent']), np.linspace(0,1,len(sample)), label='norel of large MANRS ({})'.format(len(sample)), linestyle='-')
plt.plot(np.sort(nsample['valid_percent']), np.linspace(0,1,len(nsample)), label='norel of large non-MANRS ({})'.format(len(nsample)), linestyle='-')
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample['totalPO'].sum(), nsample['totalPO'].sum())
# Out:
# total PO propagated: 1286259 435769

# %% [markdown]
# #### small networks, all rel

# %%
sample1 = small_manrs_transit_irr[small_manrs_transit_irr.relationship == 'customer']
sample2 = small_manrs_transit_irr[small_manrs_transit_irr.relationship == 'peer']
sample3 = small_manrs_transit_irr[small_manrs_transit_irr.relationship == 'norel']
plt.plot(np.sort(sample1['valid_percent']), np.linspace(0,1,len(sample1)), label='customer of small MANRS ({})'.format(len(sample1)))
plt.plot(np.sort(sample2['valid_percent']), np.linspace(0,1,len(sample2)), label='peer of small MANRS ({})'.format(len(sample2)))
plt.plot(np.sort(sample3['valid_percent']), np.linspace(0,1,len(sample3)), label='norel of small MANRS ({})'.format(len(sample3)))
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample1['totalPO'].sum(), sample2['totalPO'].sum(), sample3['totalPO'].sum())
# Out:
# total PO propagated: 409 27 168

# %% [markdown]
# #### medium network, all rel

# %%
sample1 = medium_manrs_transit_irr[medium_manrs_transit_irr.relationship == 'customer']
sample2 = medium_manrs_transit_irr[medium_manrs_transit_irr.relationship == 'peer']
sample3 = medium_manrs_transit_irr[medium_manrs_transit_irr.relationship == 'norel']
plt.plot(np.sort(sample1['valid_percent']), np.linspace(0,1,len(sample1)), label='customer of medium MANRS ({})'.format(len(sample1)))
plt.plot(np.sort(sample2['valid_percent']), np.linspace(0,1,len(sample2)), label='peer of medium MANRS ({})'.format(len(sample2)))
plt.plot(np.sort(sample3['valid_percent']), np.linspace(0,1,len(sample3)), label='norel of medium MANRS ({})'.format(len(sample3)))
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample1['totalPO'].sum(), sample2['totalPO'].sum(), sample3['totalPO'].sum())
# Out:
# total PO propagated: 49622 173 24994

# %% [markdown]
# #### large networks, all rel

# %%
sample1 = large_manrs_transit_irr[large_manrs_transit_irr.relationship == 'customer']
sample2 = large_manrs_transit_irr[large_manrs_transit_irr.relationship == 'peer']
sample3 = large_manrs_transit_irr[large_manrs_transit_irr.relationship == 'norel']
plt.plot(np.sort(sample1['valid_percent']), np.linspace(0,1,len(sample1)), label='customer of large MANRS ({})'.format(len(sample1)))
plt.plot(np.sort(sample2['valid_percent']), np.linspace(0,1,len(sample2)), label='peer of large MANRS ({})'.format(len(sample2)))
plt.plot(np.sort(sample3['valid_percent']), np.linspace(0,1,len(sample3)), label='norel of large MANRS ({})'.format(len(sample3)))
plt.xlabel('Percent of propagated prefixes with valid irr status', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend()
plt.grid()

# %%
print('total PO propagated:', sample1['totalPO'].sum(), sample2['totalPO'].sum(), sample3['totalPO'].sum())
# Out:
# total PO propagated: 528370 52543 1286259

# %% [markdown]
# ## IRR or RPKI

# %%
def irr_or_rpki(r):
    if (r['irr_status'] == 'Invalid' and r['rpki_status'] == 'NotFound') or r['rpki_status'] == 'Invalid' or r['rpki_status'] == 'Invalid,more-specific':
        return True
    return False

# %%
def irr_or_rpki_strict(r):
    if r['rpki_status'] == 'Valid' and (r['irr_status'] == 'Valid' or ['irr_status'] == 'Invalid,more-specific' ):
        return True
    return False

# %%
manrs_transit
# Out:
#                  id                 timebin           prefix      hege  af  \
# 5        1415697046  2022-05-01 00:00:00+00   46.200.62.0/24  0.006803   4
# 6        1415697043  2022-05-01 00:00:00+00    66.94.13.0/24  0.006803   4
# 7        1415697041  2022-05-01 00:00:00+00  46.201.188.0/23  0.006803   4
# 8        1415697038  2022-05-01 00:00:00+00  46.201.168.0/23  0.006803   4
# 9        1415697036  2022-05-01 00:00:00+00  46.200.168.0/23  0.006803   4
# ...             ...                     ...              ...       ...  ..
# 3677453  1411094455  2022-05-01 00:00:00+00    1.73.208.0/20  0.646259   4
# 3677454  1411094454  2022-05-01 00:00:00+00    1.73.208.0/20  0.047619   4
# 3677455  1411094452  2022-05-01 00:00:00+00     1.66.92.0/24  0.258503   4
# 3677456  1411094451  2022-05-01 00:00:00+00     1.66.92.0/24  0.367347   4
# 3677457  1411094450  2022-05-01 00:00:00+00     1.66.92.0/24  0.006803   4
#
#          visibility rpki_status             irr_status  \
# ...

# %%
manrs_transit['either_status'] = manrs_transit.apply(irr_or_rpki, axis=1)
# Out:
# /home/c4du/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
non_manrs_transit['either_status'] = non_manrs_transit.apply(irr_or_rpki, axis=1)

# %%
manrs_transit_either = manrs_transit.groupby(['asn_id', 'either_status']).size().unstack(fill_value=0).reset_index()

# %%
manrs_transit_either[manrs_transit_either.asn_id == 8075]
# Out:
# either_status  asn_id  False  True
# 78               8075    115     0

# %%
8075 in manrscdn
# Out:
# True

# %%
set(manrs).intersection(set(manrscdn))
# Out:
# {7342, 8075, 8280, 15169, 50520}

# %%
non_manrs_transit_either = non_manrs_transit.groupby(['asn_id', 'either_status']).size().unstack(fill_value=0).reset_index()

# %%
manrs_transit_either[manrs_transit_either[False] > 0]
# Out:
# either_status  asn_id   False   True
# 0                 101     181      1
# 1                 137      44      0
# 2                 174  439263  36303
# 3                 237     172      8
# 4                 271     103      0
# ..                ...     ...    ...
# 444            328073       3      0
# 445            328271       3      0
# 446            328594      43      0
# 447            328748       7      1
# 448            396450       1      0
#
# [446 rows x 3 columns]

# %%
manrs_transit_either['valid_percent'] = manrs_transit_either[True]/(manrs_transit_either[False] + manrs_transit_either[True])*100

# %%
non_manrs_transit_either['valid_percent'] = non_manrs_transit_either[True]/(non_manrs_transit_either[False] + non_manrs_transit_either[True])*100

# %%
small_manrs_transit_either = manrs_transit_either[manrs_transit_either.asn_id.isin(small)]
medium_manrs_transit_either = manrs_transit_either[manrs_transit_either.asn_id.isin(medium)]
large_manrs_transit_either = manrs_transit_either[manrs_transit_either.asn_id.isin(large)]
small_non_manrs_transit_either = non_manrs_transit_either[non_manrs_transit_either.asn_id.isin(small)]
medium_non_manrs_transit_either = non_manrs_transit_either[non_manrs_transit_either.asn_id.isin(medium)]
large_non_manrs_transit_either = non_manrs_transit_either[non_manrs_transit_either.asn_id.isin(large)]

# %% [markdown]
# #### cust vs peer

# %%
manrs_transit_either_rel = manrs_transit.groupby(['asn_id', 'relationship', 'either_status']).size().unstack(fill_value=0).reset_index()
non_manrs_transit_either_rel = non_manrs_transit.groupby(['asn_id', 'relationship', 'either_status']).size().unstack(fill_value=0).reset_index()

# %%
manrs_transit_either_rel['valid_percent'] = manrs_transit_either_rel[True]/(manrs_transit_either_rel[False] + manrs_transit_either_rel[True])*100
non_manrs_transit_either_rel['valid_percent'] = non_manrs_transit_either_rel[True]/(non_manrs_transit_either_rel[False] + non_manrs_transit_either_rel[True])*100

# %%
manrs_transit_either_peer = manrs_transit_either_rel[manrs_transit_either_rel.relationship == 'peer']
non_manrs_transit_either_peer = non_manrs_transit_either_rel[non_manrs_transit_either_rel.relationship == 'peer']

# %%
manrs_transit_either_customer = manrs_transit_either_rel[manrs_transit_either_rel.relationship == 'customer']
non_manrs_transit_either_customer = non_manrs_transit_either_rel[non_manrs_transit_either_rel.relationship == 'customer']

# %%
small_manrs_transit_either_peer = manrs_transit_either_peer[manrs_transit_either_peer.asn_id.isin(small)]
medium_manrs_transit_either_peer = manrs_transit_either_peer[manrs_transit_either_peer.asn_id.isin(medium)]
large_manrs_transit_either_peer = manrs_transit_either_peer[manrs_transit_either_peer.asn_id.isin(large)]
small_non_manrs_transit_either_peer = non_manrs_transit_either_peer[non_manrs_transit_either_peer.asn_id.isin(small)]
medium_non_manrs_transit_either_peer = non_manrs_transit_either_peer[non_manrs_transit_either_peer.asn_id.isin(medium)]
large_non_manrs_transit_either_peer = non_manrs_transit_either_peer[non_manrs_transit_either_peer.asn_id.isin(large)]

# %%
small_manrs_transit_either_customer = manrs_transit_either_customer[manrs_transit_either_customer.asn_id.isin(small)]
medium_manrs_transit_either_customer = manrs_transit_either_customer[manrs_transit_either_customer.asn_id.isin(medium)]
large_manrs_transit_either_customer = manrs_transit_either_customer[manrs_transit_either_customer.asn_id.isin(large)]
small_non_manrs_transit_either_customer = non_manrs_transit_either_customer[non_manrs_transit_either_customer.asn_id.isin(small)]
medium_non_manrs_transit_either_customer = non_manrs_transit_either_customer[non_manrs_transit_either_customer.asn_id.isin(medium)]
large_non_manrs_transit_either_customer = non_manrs_transit_either_customer[non_manrs_transit_either_customer.asn_id.isin(large)]

# %%
manrs_transit_either_rel = manrs_transit_either_rel[manrs_transit_either_rel.relationship != 'norel']
manrs_transit_either_rel = manrs_transit_either_rel[manrs_transit_either_rel.relationship != 'provider']

# %%
non_manrs_transit_either_rel = non_manrs_transit_either_rel[non_manrs_transit_either_rel.relationship != 'norel']
non_manrs_transit_either_rel = non_manrs_transit_either_rel[non_manrs_transit_either_rel.relationship != 'provider']

# %%
manrs_transit_either_rel['totalPO'] = manrs_transit_either_rel[False] + manrs_transit_either_rel[True]

# %%
manrs_transit_either_rel_isp = manrs_transit_either_rel[manrs_transit_either_rel.relationship != 'peer']

# %%
non_manrs_transit_either_rel_isp = non_manrs_transit_either_rel[non_manrs_transit_either_rel.relationship != 'peer']

# %%
small_manrs_transit_either_rel_isp = manrs_transit_either_rel_isp[manrs_transit_either_rel_isp.asn_id.isin(small)]
medium_manrs_transit_either_rel_isp = manrs_transit_either_rel_isp[manrs_transit_either_rel_isp.asn_id.isin(medium)]
large_manrs_transit_either_rel_isp = manrs_transit_either_rel_isp[manrs_transit_either_rel_isp.asn_id.isin(large)]
small_non_manrs_transit_either_rel_isp = non_manrs_transit_either_rel_isp[non_manrs_transit_either_rel_isp.asn_id.isin(small)]
medium_non_manrs_transit_either_rel_isp = non_manrs_transit_either_rel_isp[non_manrs_transit_either_rel_isp.asn_id.isin(medium)]
large_non_manrs_transit_either_rel_isp = non_manrs_transit_either_rel_isp[non_manrs_transit_either_rel_isp.asn_id.isin(large)]

# %%
plt.plot(np.sort(small_manrs_transit_either_rel_isp['valid_percent']), np.linspace(0,1,len(small_manrs_transit_either_rel_isp)), label='small MANRS (449)', linestyle='-')
plt.plot(np.sort(small_non_manrs_transit_either_rel_isp['valid_percent']), np.linspace(0,1,len(small_non_manrs_transit_either_rel_isp)), label='small non-MANRS (68,385)', linestyle='-')
plt.plot(np.sort(medium_manrs_transit_either_rel_isp['valid_percent']), np.linspace(0,1,len(medium_manrs_transit_either_rel_isp)), label='medium MANRS (315)', linestyle='--')
plt.plot(np.sort(medium_non_manrs_transit_either_rel_isp['valid_percent']), np.linspace(0,1,len(medium_non_manrs_transit_either_rel_isp)), label='medium non-MANRS (4,493)', linestyle='--')
plt.plot(np.sort(large_manrs_transit_either_rel_isp['valid_percent']), np.linspace(0,1,len(large_manrs_transit_either_rel_isp)), label='large MANRS (24)', linestyle='-.')
plt.plot(np.sort(large_non_manrs_transit_either_rel_isp['valid_percent']), np.linspace(0,1,len(large_non_manrs_transit_either_rel_isp)), label='large non-MANRS (86)', linestyle='-.')
plt.axvline(x=10, linestyle=':', color='blue', linewidth=1.25)
plt.text(7, -0.14, '10', color='blue', size=13)
plt.xlabel('Percent of propagated MANRS-incompliant prefixes', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(-2, 25)
plt.legend(prop={'size':11})
plt.grid()

# %%
a = len(small_manrs_transit_either_rel_isp)
b = len(small_manrs_transit_either_rel_isp[small_manrs_transit_either_rel_isp.valid_percent <= 10])
print(b,a,b/a)

a = len(medium_manrs_transit_either_rel_isp)
b = len(medium_manrs_transit_either_rel_isp[medium_manrs_transit_either_rel_isp.valid_percent <= 10])
print(b,a,b/a)

a = len(large_manrs_transit_either_rel_isp)
b = len(large_manrs_transit_either_rel_isp[large_manrs_transit_either_rel_isp.valid_percent <= 10])
print(b,a,b/a)
# Out:
# 98 99 0.98989898989899
# 295 311 0.9485530546623794
# 23 24 0.9583333333333334

# %%
manrs_transit_either_rel[manrs_transit_either_rel.asn_id.isin(manrscdn)]
# Out:
# either_status  asn_id relationship  False  True  valid_percent  totalPO
# 131              7342     customer     92     0       0.000000       92
# 151              8075     customer    111     0       0.000000      111
# 158              8280     customer     39     0       0.000000       39
# 223             13335     customer   1773     3       0.168919     1776
# 225             13335         peer     16     0       0.000000       16
# 232             14061     customer     18     0       0.000000       18
# 246             15169     customer   1684     0       0.000000     1684
# 261             16509     customer    629     3       0.474684      632
# 281             20473     customer   1079     2       0.185014     1081
# 287             20940     customer   4025   258       6.023815     4283
# 391             32934     customer     14     0       0.000000       14
# 521             50520     customer      5     0       0.000000        5
# ...

# %%
manrs_transit_either[manrs_transit_either.asn_id.isin(manrscdn)]
# Out:
# either_status  asn_id  False  True  valid_percent
# 67               7342     92     0       0.000000
# 78               8075    115     0       0.000000
# 82               8280     48     0       0.000000
# 121             13335   1796     3       0.166759
# 125             14061     18     0       0.000000
# 134             15169   1684     0       0.000000
# 144             16509    629     3       0.474684
# 156             20473   1107     5       0.449640
# 160             20940   4025   261       6.089594
# 226             32934     14     0       0.000000
# 311             50520      5     0       0.000000
# 333             54825     58     2       3.333333
# 345             59414      9     0       0.000000
# 367            133800      2     0       0.000000

# %%
manrs_transit
# Out:
#                  id                 timebin           prefix      hege  af  \
# 5        1415697046  2022-05-01 00:00:00+00   46.200.62.0/24  0.006803   4
# 6        1415697043  2022-05-01 00:00:00+00    66.94.13.0/24  0.006803   4
# 7        1415697041  2022-05-01 00:00:00+00  46.201.188.0/23  0.006803   4
# 8        1415697038  2022-05-01 00:00:00+00  46.201.168.0/23  0.006803   4
# 9        1415697036  2022-05-01 00:00:00+00  46.200.168.0/23  0.006803   4
# ...             ...                     ...              ...       ...  ..
# 3677453  1411094455  2022-05-01 00:00:00+00    1.73.208.0/20  0.646259   4
# 3677454  1411094454  2022-05-01 00:00:00+00    1.73.208.0/20  0.047619   4
# 3677455  1411094452  2022-05-01 00:00:00+00     1.66.92.0/24  0.258503   4
# 3677456  1411094451  2022-05-01 00:00:00+00     1.66.92.0/24  0.367347   4
# 3677457  1411094450  2022-05-01 00:00:00+00     1.66.92.0/24  0.006803   4
#
#          visibility rpki_status             irr_status  \
# ...

# %%
manrs_transit_either_rel[manrs_transit_either_rel.asn_id.isin(manrscdn)]
# Out:
# either_status  asn_id relationship  False  True  valid_percent  totalPO
# 129              7342     customer     82     0       0.000000       82
# 148              8075     customer    112     0       0.000000      112
# 154              8280     customer     33     0       0.000000       33
# 220             13335     customer   2087    17       0.807985     2104
# 221             13335         peer     16     0       0.000000       16
# 228             14061     customer     18     0       0.000000       18
# 242             15169     customer   1865     0       0.000000     1865
# 257             16509     customer    642     2       0.310559      644
# 276             20473     customer   1110     3       0.269542     1113
# 282             20940     customer   3992   252       5.937795     4244
# 379             32934     customer     14     0       0.000000       14
# 505             50520     customer      5     0       0.000000        5
# ...

# %%
manrs_transit_either_rel_isp
# Out:
# either_status  asn_id relationship   False  True  valid_percent  totalPO
# 0                 101     customer     116     0       0.000000      116
# 2                 137     customer      42     1       2.325581       43
# 4                 174     customer  140480  7822       5.274373   148302
# 7                 237     customer     132     5       3.649635      137
# 9                 271     customer     102     0       0.000000      102
# ..                ...          ...     ...   ...            ...      ...
# 701            328073     customer       3     0       0.000000        3
# 702            328271     customer       1     1      50.000000        2
# 703            328594     customer      41     0       0.000000       41
# 705            328748     customer       8     0       0.000000        8
# 706            396450     customer       3     0       0.000000        3
#
# [435 rows x 6 columns]

# %%
manrs_transit_either_combined_isp = manrs_transit_either_rel.groupby(['asn_id']).agg({False: 'sum', True:'sum', 'totalPO':'sum'}).reset_index()

# %%
manrs_transit_either_combined['valid_percent'] = manrs_transit_either_combined[True] / manrs_transit_either_combined['totalPO']*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28912/4256650851.py in <module>
# ----> 1 manrs_transit_either_combined['valid_percent'] = manrs_transit_either_combined[True] / manrs_transit_either_combined['totalPO']*100
#
# NameError: name 'manrs_transit_either_combined' is not defined

# %%
small_manrs_transit_either_combined = manrs_transit_either_combined[manrs_transit_either_combined.asn_id.isin(small)]
medium_manrs_transit_either_combined = manrs_transit_either_combined[manrs_transit_either_combined.asn_id.isin(medium)]
large_manrs_transit_either_combined = manrs_transit_either_combined[manrs_transit_either_combined.asn_id.isin(large)]

# %% [markdown]
# ### scatter plot: # compliant pfx vs # non-compliant pfx

# %%
plt.scatter(manrs_transit_either[manrs_transit_either.asn_id.isin(small_manrs)][True]+0.1, manrs_transit_either[manrs_transit_either.asn_id.isin(small_manrs)][False]+0.1, label='small MANRS')
plt.scatter(manrs_transit_either[manrs_transit_either.asn_id.isin(medium_manrs)][True]+0.1, manrs_transit_either[manrs_transit_either.asn_id.isin(medium_manrs)][False]+0.1, label='medium MANRS')
plt.scatter(manrs_transit_either[manrs_transit_either.asn_id.isin(large_manrs)][True]+0.1, manrs_transit_either[manrs_transit_either.asn_id.isin(large_manrs)][False]+0.1, label='large MANRS')
plt.xlabel('# of MANRS Action 4 Compliant Prefixes')
plt.ylabel('# of MANRS Action 4 NON Compliant Prefixes')
plt.yscale('log')
plt.xscale('log')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size':11})
plt.grid()
plt.savefig('manrs1compliantscatter.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.scatter(manrs_transit_either_peer[manrs_transit_either_peer.asn_id.isin(small_manrs)][True]+0.1, manrs_transit_either_peer[manrs_transit_either_peer.asn_id.isin(small_manrs)][False]+0.1, label='small MANRS')
plt.scatter(manrs_transit_either_peer[manrs_transit_either_peer.asn_id.isin(medium_manrs)][True]+0.1, manrs_transit_either_peer[manrs_transit_either_peer.asn_id.isin(medium_manrs)][False]+0.1, label='medium MANRS')
plt.scatter(manrs_transit_either_peer[manrs_transit_either_peer.asn_id.isin(large_manrs)][True]+0.1, manrs_transit_either_peer[manrs_transit_either_peer.asn_id.isin(large_manrs)][False]+0.1, label='large MANRS')
plt.xlabel('# of MANRS Action 4 Compliant Prefixes')
plt.ylabel('# of MANRS Action 4 NON Compliant Prefixes')
plt.yscale('log')
plt.xscale('log')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size':11})
plt.grid()
#plt.savefig('manrs1compliantscatter.eps', bbox_inches='tight')

# %%
manrs_transit_either_peer
# Out:
# either_status  asn_id relationship  False  True  valid_percent
# 6                 174         peer   3748  8245      68.748437
# 34               1299         peer   3968  8017      66.891948
# 43               1916         peer     52     2       3.703704
# 48               2381         peer      0     1     100.000000
# 54               2516         peer      0    35     100.000000
# 61               2603         peer      1    20      95.238095
# 66               2914         peer   2280  4029      63.861151
# 74               3303         peer      0     1     100.000000
# 78               3356         peer   5077  9948      66.209651
# 81               3549         peer      0     1     100.000000
# 88               4134         peer      0     4     100.000000
# 101              4809         peer      0     6     100.000000
# 104              5050         peer      0     7     100.000000
# 112              5511         peer      0    13     100.000000
# ...

# %%
transitdf[transitdf.asn_id == 101]
# Out:
#                  id                 timebin            prefix      hege  af  \
# 32278    1415648158  2022-05-01 00:00:00+00   137.75.112.0/22  1.000000   4
# 49093    1415628617  2022-05-01 00:00:00+00    69.166.62.0/24  0.687075   4
# 58271    1415617096  2022-05-01 00:00:00+00    164.110.0.0/16  0.857143   4
# 59323    1415616405  2022-05-01 00:00:00+00     153.90.0.0/16  1.000000   4
# 91369    1415578343  2022-05-01 00:00:00+00  164.116.252.0/24  1.000000   4
# ...             ...                     ...               ...       ...  ..
# 2490822  1412615979  2022-05-01 00:00:00+00   72.233.128.0/18  1.000000   4
# 2490828  1412615972  2022-05-01 00:00:00+00   72.233.148.0/22  0.952381   4
# 2523152  1412576700  2022-05-01 00:00:00+00    162.78.64.0/18  0.027211   4
# 2776139  1412266853  2022-05-01 00:00:00+00  207.196.128.0/24  0.074830   4
# 3300952  1411583032  2022-05-01 00:00:00+00   162.78.192.0/18  0.027211   4
#
# ...

# %%
manrs_transit_either_customer
# Out:
# either_status  asn_id relationship  False    True  valid_percent
# 0                 101     customer      0     116     100.000000
# 2                 137     customer      1      42      97.674419
# 4                 174     customer  10957  137345      92.611698
# 7                 237     customer      5     132      96.350365
# 9                 271     customer      0     102     100.000000
# ..                ...          ...    ...     ...            ...
# 701            328073     customer      0       3     100.000000
# 702            328271     customer      1       1      50.000000
# 703            328594     customer      0      41     100.000000
# 705            328748     customer      0       8     100.000000
# 706            396450     customer      0       3     100.000000
#
# [435 rows x 5 columns]

# %%
plt.scatter(manrs_transit_either_customer[manrs_transit_either_customer.asn_id.isin(small_manrs)][True]+0.1, manrs_transit_either_customer[manrs_transit_either_customer.asn_id.isin(small_manrs)][False]+0.1, label='small MANRS')
plt.scatter(manrs_transit_either_customer[manrs_transit_either_customer.asn_id.isin(medium_manrs)][True]+0.1, manrs_transit_either_customer[manrs_transit_either_customer.asn_id.isin(medium_manrs)][False]+0.1, label='medium MANRS')
plt.scatter(manrs_transit_either_customer[manrs_transit_either_customer.asn_id.isin(large_manrs)][True]+0.1, manrs_transit_either_customer[manrs_transit_either_customer.asn_id.isin(large_manrs)][False]+0.1, label='large MANRS')
plt.xlabel('# of MANRS Action 4 Compliant Prefixes')
plt.ylabel('# of MANRS Action 4 NON Compliant Prefixes')
plt.yscale('log')
plt.xscale('log')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size':11})
plt.grid()

# %% [markdown]
# consider irr invalid more specific as valid

# %%
manrs_transit_either[manrs_transit_either[True] == 0]
# Out:
# either_status  asn_id  False  True  valid_percent
# 5                 278      9     0            0.0
# 163             22122      2     0            0.0
# 183             26415      2     0            0.0

# %%
manrs_transit[manrs_transit.asn_id==271915]
# Out:
#                  id                 timebin            prefix  hege  af  \
# 31030    1415649615  2022-05-01 00:00:00+00   141.136.57.0/24   1.0   4
# 93139    1415575816  2022-05-01 00:00:00+00    161.22.36.0/24   1.0   4
# 2297749  1412848466  2022-05-01 00:00:00+00  189.127.167.0/24   1.0   4
#
#          visibility rpki_status irr_status delegated_prefix_status  \
# 31030     97.814208       Valid      Valid                assigned
# 93139     98.360656       Valid      Valid                assigned
# 2297749   99.453552       Valid      Valid                assigned
#
#         delegated_asn_status  \
# 31030               assigned
# 93139               assigned
# 2297749             assigned
#
#                                                      descr moas  asn_id  \
# 31030                                 ITX-CUSTOMER-VIGINET    f  271915
# 93139    LACNIC generated route for TOP COMUNICATIONS E...    f  271915
# ...

# %% [markdown]
# ### CDF: percentage of compliant networks

# %%
plt.plot(np.sort(small_manrs_transit_either['valid_percent']), np.linspace(0,1,len(small_manrs_transit_either)), label='small MANRS (449)', linestyle='-')
plt.plot(np.sort(small_non_manrs_transit_either['valid_percent']), np.linspace(0,1,len(small_non_manrs_transit_either)), label='small non-MANRS (68,385)', linestyle='-')
plt.plot(np.sort(medium_manrs_transit_either['valid_percent']), np.linspace(0,1,len(medium_manrs_transit_either)), label='medium MANRS (315)', linestyle='--')
plt.plot(np.sort(medium_non_manrs_transit_either['valid_percent']), np.linspace(0,1,len(medium_non_manrs_transit_either)), label='medium non-MANRS (4,493)', linestyle='--')
plt.plot(np.sort(large_manrs_transit_either['valid_percent']), np.linspace(0,1,len(large_manrs_transit_either)), label='large MANRS (24)', linestyle='-.')
plt.plot(np.sort(large_non_manrs_transit_either['valid_percent']), np.linspace(0,1,len(large_non_manrs_transit_either)), label='large non-MANRS (86)', linestyle='-.')
plt.axvline(x=90, linestyle=':', color='blue', linewidth=1.25)
plt.text(87, -0.14, '90', color='blue', size=13)
plt.xlabel('Percent of propagated MANRS-compliant prefixes', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size':11})
plt.grid()
#plt.savefig('manrstransiteither.eps', bbox_inches='tight')

# %%
small_manrs_transit_either
# Out:
# either_status  asn_id  False  True  valid_percent
# 5                 278      9     0            0.0
# 19               1403      0     1          100.0
# 31               2602      0     2          100.0
# 39               3333      0     1          100.0
# 47               4323      0     3          100.0
# ..                ...    ...   ...            ...
# 445            327687      0     9          100.0
# 446            327700      0     2          100.0
# 447            328073      0     3          100.0
# 448            328271      1     1           50.0
# 451            396450      0     3          100.0
#
# [118 rows x 4 columns]

# %%
plt.plot(np.sort(small_manrs_transit_either_peer['valid_percent']), np.linspace(0,1,len(small_manrs_transit_either_peer)), label='small MANRS (449)', linestyle='-')
plt.plot(np.sort(small_non_manrs_transit_either_peer['valid_percent']), np.linspace(0,1,len(small_non_manrs_transit_either_peer)), label='small non-MANRS (68,385)', linestyle='-')
plt.plot(np.sort(medium_manrs_transit_either_peer['valid_percent']), np.linspace(0,1,len(medium_manrs_transit_either_peer)), label='medium MANRS (315)', linestyle='--')
plt.plot(np.sort(medium_non_manrs_transit_either_peer['valid_percent']), np.linspace(0,1,len(medium_non_manrs_transit_either_peer)), label='medium non-MANRS (4,493)', linestyle='--')
plt.plot(np.sort(large_manrs_transit_either_peer['valid_percent']), np.linspace(0,1,len(large_manrs_transit_either_peer)), label='large MANRS (24)', linestyle='-.')
plt.plot(np.sort(large_non_manrs_transit_either_peer['valid_percent']), np.linspace(0,1,len(large_non_manrs_transit_either_peer)), label='large non-MANRS (86)', linestyle='-.')
plt.axvline(x=90, linestyle=':', color='blue', linewidth=1.25)
plt.text(87, -0.14, '90', color='blue', size=13)
plt.xlabel('Percent of propagated MANRS-compliant peer prefixes', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size':11})
plt.grid()
plt.savefig('manrstransiteitherpeer.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.plot(np.sort(small_manrs_transit_either_customer['valid_percent']), np.linspace(0,1,len(small_manrs_transit_either_customer)), label='small MANRS (449)', linestyle='-')
plt.plot(np.sort(small_non_manrs_transit_either_customer['valid_percent']), np.linspace(0,1,len(small_non_manrs_transit_either_customer)), label='small non-MANRS (68,385)', linestyle='-')
plt.plot(np.sort(medium_manrs_transit_either_customer['valid_percent']), np.linspace(0,1,len(medium_manrs_transit_either_customer)), label='medium MANRS (315)', linestyle='--')
plt.plot(np.sort(medium_non_manrs_transit_either_customer['valid_percent']), np.linspace(0,1,len(medium_non_manrs_transit_either_customer)), label='medium non-MANRS (4,493)', linestyle='--')
plt.plot(np.sort(large_manrs_transit_either_customer['valid_percent']), np.linspace(0,1,len(large_manrs_transit_either_customer)), label='large MANRS (24)', linestyle='-.')
plt.plot(np.sort(large_non_manrs_transit_either_customer['valid_percent']), np.linspace(0,1,len(large_non_manrs_transit_either_customer)), label='large non-MANRS (86)', linestyle='-.')
plt.axvline(x=90, linestyle=':', color='blue', linewidth=1.25)
plt.text(87, -0.14, '90', color='blue', size=13)
plt.xlabel('Percent of propagated MANRS-compliant customer prefixes', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size':11})
plt.grid()
plt.savefig('manrstransiteithercustomer.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
manrs_transit_either['90_compliant'] = manrs_transit_either.apply(lambda x: x[True]/(x[True]+x[False]), axis=1)

# %%
manrs_transit_either[manrs_transit_either['90_compliant'] < 0.9].sort_values('90_compliant', ascending=True)
# Out:
# either_status  asn_id  False    True  valid_percent  90_compliant
# 5                 278      9       0       0.000000      0.000000
# 183             26415      2       0       0.000000      0.000000
# 163             22122      2       0       0.000000      0.000000
# 48               4538     57       9      13.636364      0.136364
# 193             28005      4       2      33.333333      0.333333
# 241             33666      7       4      36.363636      0.363636
# 448            328271      1       1      50.000000      0.500000
# 234             33654      3       4      57.142857      0.571429
# 195             28022      7      10      58.823529      0.588235
# 157             20928     36      56      60.869565      0.608696
# 230             33588     17      29      63.043478      0.630435
# 342             59766      1       2      66.666667      0.666667
# 164             22258      2       4      66.666667      0.666667
# ...

# %%
len(manrs_transit_either[manrs_transit_either['90_compliant'] < 0.9])
# Out:
# 39

# %% [markdown]
# ### compliance vs age

# %%
as_entry_df = pd.read_csv('manrs_entry_date.csv.gz')

# %%
as_entry_df['asn'] = as_entry_df['asn'].apply(int)

# %%
manrs_transit_either = manrs_transit_either.merge(as_entry_df, left_on='asn_id', right_on='asn', how='left')

# %%
def delta_date(x):
    if pd.isnull(x):
        return
    x = datetime.strptime(x, '%Y-%m-%d')
    y = datetime.strptime('2022-04-27', '%Y-%m-%d')
    return (y-x).days

# %%
manrs_transit_either['age'] = manrs_transit_either['date'].apply(delta_date)

# %%
manrs_transit_either
# Out:
#      asn_id  False    True  valid_percent  90_compliant       asn        date  \
# 0       101      0     179     100.000000      1.000000       NaN         NaN
# 1       137      1      44      97.777778      0.977778     137.0  2020-07-20
# 2       174  50876  406900      88.886268      0.888863     174.0  2015-07-24
# 3       237      7     182      96.296296      0.962963     237.0  2018-06-29
# 4       271      0     104     100.000000      1.000000     271.0  2021-09-22
# ..      ...    ...     ...            ...           ...       ...         ...
# 447  328073      0       3     100.000000      1.000000  328073.0  2019-11-11
# 448  328271      1       1      50.000000      0.500000  328271.0  2020-07-27
# 449  328594      0      42     100.000000      1.000000  328594.0  2021-10-21
# 450  328748      0       8     100.000000      1.000000       NaN         NaN
# 451  396450      0       3     100.000000      1.000000       NaN         NaN
#
#          rir     age
# ...

# %%
manrs_transit_either[manrs_transit_either.asn_id==2914]
# Out:
#     asn_id  False    True  valid_percent  90_compliant     asn        date  \
# 34    2914  25826  208126      88.960983       0.88961  2914.0  2014-11-01
#
#      rir     age
# 34  ARIN  2734.0

# %%
manrs_transit_either[(manrs_transit_either.asn_id.isin(manrscdn))].sort_values(False, ascending=False)
# Out:
#      asn_id  False  True  valid_percent  90_compliant       asn        date  \
# 158   20940    254  3992      94.017899      0.940179   20940.0  2020-04-01
# 120   13335     21  2099      99.009434      0.990094   13335.0  2020-04-01
# 143   16509      2   642      99.689441      0.996894   16509.0  2020-04-01
# 154   20473      1  1124      99.911111      0.999111   20473.0  2020-04-01
# 329   54825      1    58      98.305085      0.983051   54825.0  2020-04-01
# 66     7342      0    82     100.000000      1.000000    7342.0  2017-06-04
# 77     8075      0   112     100.000000      1.000000    8075.0  2019-04-09
# 81     8280      0    41     100.000000      1.000000    8280.0  2020-06-16
# 124   14061      0    18     100.000000      1.000000   14061.0  2020-04-01
# 133   15169      0  1865     100.000000      1.000000   15169.0  2019-02-22
# 223   32934      0    14     100.000000      1.000000   32934.0  2020-04-01
# ...

# %%
manrs_transit_either[(manrs_transit_either.asn_id.isin(manrs)) & (manrs_transit_either.valid_percent < 90)].sort_values(False, ascending=False)
# Out:
#      asn_id  False    True  valid_percent  90_compliant       asn        date  \
# 40     3356  57736  444700      88.508785      0.885088    3356.0  2014-11-01
# 18     1299  56198  433486      88.523619      0.885236    1299.0  2018-09-11
# 2       174  50876  406900      88.886268      0.888863     174.0  2015-07-24
# 34     2914  25826  208126      88.960983      0.889610    2914.0  2014-11-01
# 41     3549   1075    6434      85.683846      0.856838    3549.0  2014-11-01
# 23     1916     57     404      87.635575      0.876356    1916.0  2019-12-11
# 48     4538     57       9      13.636364      0.136364    4538.0  2014-11-01
# 242   33667     48     241      83.391003      0.833910   33667.0  2014-11-01
# 232   33651     42     180      81.081081      0.810811   33651.0  2014-11-01
# 229   33491     38     315      89.235127      0.892351   33491.0  2014-11-01
# 157   20928     36      56      60.869565      0.608696   20928.0  2015-04-10
# ...

# %%
small_manrs_transit_either = manrs_transit_either[manrs_transit_either.asn_id.isin(small)]
medium_manrs_transit_either = manrs_transit_either[manrs_transit_either.asn_id.isin(medium)]
large_manrs_transit_either = manrs_transit_either[manrs_transit_either.asn_id.isin(large)]

# %%
plt.scatter(small_manrs_transit_either['age']/365, small_manrs_transit_either['valid_percent'], label='small')
plt.scatter(medium_manrs_transit_either['age']/365, medium_manrs_transit_either['valid_percent'], label='medium')
plt.scatter(large_manrs_transit_either['age']/365, large_manrs_transit_either['valid_percent'], label='large')
plt.xlabel('# of years since AS joined MANRS', fontsize=12)
plt.ylabel('% valid prefixes', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.axhline(y=90, linestyle='-', color='blue', linewidth=1.5)
plt.text(-0.65, 87, '90', color='blue', size=13)
plt.legend(prop={'size':10})
plt.grid()
plt.savefig('manrs1complianceage.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### organization level compliance

# %%
manrs_transit_either['org'] = manrs_transit_either['asn_id'].apply(lambda x: manrs_org[x])

# %%
def org_level_compliance(l):
    return len(l[l>=90])/len(l) >= 0.5

# %%
org_compliance = manrs_transit_either.groupby('org').agg({'valid_percent': org_level_compliance, 'age':'first'})

# %%
org_compliance[org_compliance.valid_percent == False]
# Out:
#                                                    valid_percent     age
# org
# Alaska Communications                                      False   751.0
# Arelion                                                    False  1324.0
# CERNET                                                     False  2734.0
# CenturyLink                                                False  2734.0
# Cogent Communications Inc.                                 False  2469.0
# Comteco RL                                                 False  1016.0
# Costa Rica Internet Service Provider (CRISP S.A.)          False   181.0
# Digicel Panama                                             False   927.0
# HopOne Internet Corp.                                      False  1301.0
# IVeloz Telecom Serv. em Telecomunicacoes LTDA              False   861.0
# Justweb telecomunicações LTDA                              False  1225.0
# NOOR Data Networks                                         False  2574.0
# ...

# %%
plt.scatter(org_compliance['age']/365, org_compliance['valid_percent'])

# %%
manrs_transit_either[manrs_transit_either.org == 'Comcast'].sum()
# Out:
# asn_id                                                      701253
# False                                                          600
# True                                                          6154
# valid_percent                                          2239.907432
# 90_compliant                                             22.399074
# asn                                                       701253.0
# date             2014-11-012014-11-012014-11-012014-11-012014-1...
# rir              ARINARINARINARINARINARINARINARINARINARINARINAR...
# age                                                        71084.0
# org              ComcastComcastComcastComcastComcastComcastComc...
# dtype: object

# %% [markdown]
# #### comcast case

# %%
comcast = manrs_transit_either[manrs_transit_either.org == 'Comcast']

# %%
non_manrs_transit_either[non_manrs_transit_either.asn_id.isin(sibling_actually_not_in_manrs['Akamai Technologies'])]
# Out:
# either_status  asn_id  False  True  valid_percent
# 3853            34164      0     4          100.0

# %%
comcast
# Out:
#      asn_id  False  True  valid_percent  90_compliant      asn        date  \
# 64     7015     13   250      95.057034      0.950570   7015.0  2014-11-01
# 65     7016     13   141      91.558442      0.915584   7016.0  2014-11-01
# 71     7725     14    70      83.333333      0.833333   7725.0  2014-11-01
# 76     7922    310  3800      92.457421      0.924574   7922.0  2014-11-01
# 121   13367     11    71      86.585366      0.865854  13367.0  2014-11-01
# 153   20214      1    14      93.333333      0.933333  20214.0  2014-11-01
# 160   21508      3    45      93.750000      0.937500  21508.0  2014-11-01
# 164   22258      2     4      66.666667      0.666667  22258.0  2014-11-01
# 168   22909      3    35      92.105263      0.921053  22909.0  2014-11-01
# 225   33287     14   153      91.616766      0.916168  33287.0  2014-11-01
# 227   33489      2    14      87.500000      0.875000  33489.0  2014-11-01
# ...

# %%
manrs_transit[manrs_transit.asn_id.isin(comcast.asn_id)].groupby(['asn_id', 'irr_status', 'rpki_status']).size().unstack(fill_value=0)
# Out:
# rpki_status                   Invalid  Invalid,more-specific  NotFound  Valid
# asn_id irr_status
# 7015   Invalid                      0                      0         6     17
#        Invalid,more-specific        0                      2        76      3
#        NotFound                     0                      0         7      0
#        Valid                        0                      0       132     20
# 7016   Invalid                      0                      0        11      8
#        Invalid,more-specific        0                      0        51      0
#        NotFound                     0                      0         2      0
#        Valid                        0                      0        72     10
# 7725   Invalid                      0                      0         9      9
#        Invalid,more-specific        0                      0        16      2
#        NotFound                     0                      0         5      0
# ...

# %%
# manrs_transit[manrs_transit.asn_id.isin(comcast.asn_id)].to_csv('comcast_case.csv.gz')

# %%
manrs_transit[manrs_transit.asn_id.isin(comcast.asn_id)].groupby(['asn_id', 'rpki_status', 'irr_status']).size().unstack(fill_value=0)
# Out:
# irr_status                    Invalid  Invalid,more-specific  NotFound  Valid
# asn_id rpki_status
# 7015   Invalid,more-specific        0                      2         0      0
#        NotFound                     6                     76         7    132
#        Valid                       17                      3         0     20
# 7016   NotFound                    11                     51         2     72
#        Valid                        8                      0         0     10
# 7725   NotFound                     9                     16         5     33
#        Valid                        9                      2         0     10
# 7922   Invalid                      2                      1         0      0
#        Invalid,more-specific        0                      2         0      0
#        NotFound                   232                   1234        76   2017
#        Valid                      195                     28         0    323
# ...

# %% [markdown]
# #### akamai case

# %%
manrs_transit_either[manrs_transit_either.asn_id == 20940]
# Out:
#      asn_id  False  True  valid_percent  90_compliant      asn        date  \
# 158   20940    254  3992      94.017899      0.940179  20940.0  2020-04-01
#
#       rir    age                  org
# 158  RIPE  756.0  Akamai Technologies

# %%
non_manrs_transit_either[non_manrs_transit_either.asn_id.isin(sibling_actually_not_in_manrs['Akamai Technologies'])]
# Out:
# either_status  asn_id  False  True  valid_percent
# 3853            34164      0     4          100.0

# %%
manrs_transit[(manrs_transit.asn_id == 20940) & (manrs_transit.irr_status == 'Invalid') & (manrs_transit.rpki_status != 'Valid')]
# Out:
#                  id                 timebin           prefix      hege  af  \
# 349744   1415266978  2022-05-01 00:00:00+00   23.216.16.0/20  1.000000   4
# 357890   1415257517  2022-05-01 00:00:00+00    23.58.96.0/20  1.000000   4
# 359549   1415255460  2022-05-01 00:00:00+00  104.91.240.0/22  1.000000   4
# 360082   1415254434  2022-05-01 00:00:00+00    23.63.16.0/22  1.000000   4
# 360832   1415253913  2022-05-01 00:00:00+00   104.81.16.0/20  1.000000   4
# ...             ...                     ...              ...       ...  ..
# 3338620  1411534914  2022-05-01 00:00:00+00   23.61.128.0/19  1.000000   4
# 3338624  1411534909  2022-05-01 00:00:00+00   23.56.208.0/24  1.000000   4
# 3338924  1411535129  2022-05-01 00:00:00+00  104.115.96.0/19  1.000000   4
# 3339031  1411535000  2022-05-01 00:00:00+00  23.195.160.0/19  1.000000   4
# 3612637  1411181481  2022-05-01 00:00:00+00   173.223.6.0/24  0.687075   4
#
# ...

# %%
non_manrs_transit[non_manrs_transit.asn_id==34164].groupby(['asn_id', 'rpki_status', 'irr_status']).size().unstack(fill_value=0)
# Out:
# irr_status          Valid
# asn_id rpki_status
# 34164  Valid            4

# %%
sibling_not_in_manrs['Akamai Technologies']
# Out:
# [21342,
#  21357,
#  21399,
#  31107,
#  31108,
#  31109,
#  31110,
#  31377,
#  33905,
#  34164,
#  34850,
#  35204,
#  39836,
#  43639,
#  48163,
#  49249,
#  49846,
#  200005,
#  213120]

# %%
manrs_org2as['Akamai Technologies']
# Out:
# [20940]

# %%
mapping[20940]
# Out:
# ('Akamai International B.V.', 'NL')

# %%
org2as['Akamai International B.V.']
# Out:
# []

# %% [markdown]
# # longitudinal compliance

# %%
longdataset = ihr[-85::7]

# %%
longdataset[6] = '/project/manic-geo/irr/ihr/origin_2022-03-21.csv.gz'
longdataset[9] = '/project/manic-geo/irr/ihr/origin_2022-04-12.csv.gz'

# %%
longdataset
# Out:
# ['/project/manic-geo/irr/ihr/origin_2022-02-10.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-02-17.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-02-24.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-03-03.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-03-10.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-03-17.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-03-21.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-03-31.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-04-07.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-04-12.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-04-21.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_2022-04-28.csv.gz',
#  '/project/manic-geo/irr/ihr/origin_v4_2022-05-01.csv.gz']

# %%
def as_compliance_check(f):
    date = datetime.strptime(f[-17:-7], '%Y-%m-%d')
    df = pd.read_csv(f, index_col=0)
    df = df[df.asn_id.isin(manrsas)]
    df['either_status'] = df.apply(irr_or_rpki, axis=1)
    #df['either_status_strict'+date] = df.apply(irr_or_rpki_strict, axis=1)
    df_either = df.groupby(['asn_id', 'either_status']).size().unstack(fill_value=0).reset_index()
    df_either['valid_percent'] = df_either[True]/(df_either[False] + df_either[True])*100
    df_either['date'] = date
    return df_either[['asn_id', 'valid_percent', 'date']]

# %%
l = []
for i in ihr[-85::7]:
    try:
        l.append(as_compliance_check(i))
    except:
        print(i)
        pass
# Out:
# /project/manic-geo/irr/ihr/origin_2022-03-20.csv.gz
# /project/manic-geo/irr/ihr/origin_2022-04-03.csv.gz

# %%
# if __name__ == '__main__':
#     try:
#         pool = mp.Pool(12)
#         lcompliance = pool.map(as_compliance_check, ihr[-85::7])
#     finally:
#         pool.close()
#         pool.join()

# %%
lc = pd.concat(l, ignore_index=True)

# %%
lc
# Out:
# either_status  originasn_id  valid_percent       date
# 0                        87     100.000000 2022-02-06
# 1                        88     100.000000 2022-02-06
# 2                        92     100.000000 2022-02-06
# 3                       101     100.000000 2022-02-06
# 4                       103      95.833333 2022-02-06
# ...                     ...            ...        ...
# 8514                 395262     100.000000 2022-05-01
# 8515                 396955      94.117647 2022-05-01
# 8516                 396961     100.000000 2022-05-01
# 8517                 398866     100.000000 2022-05-01
# 8518                 399214     100.000000 2022-05-01
#
# [8519 rows x 3 columns]

# %%
def count_incompliance_cdn(l):
    l = np.array(l)
    return len(l[l < 100])

# %%
def count_incompliance_isp(l):
    l = np.array(l)
    return len(l[l < 90])

# %%
len(l)
# Out:
# 11

# %%
cdnincompliance = lc[lc.asn_id.isin(manrscdn)].groupby(['asn_id']).agg({'valid_percent':count_incompliance_cdn})

# %%
cdnincompliance
# Out:
# either_status  valid_percent
# originasn_id
# 2906                       0
# 7342                       0
# 8075                       3
# 8280                       0
# 13335                     11
# 14061                      0
# 15169                      0
# 16509                     11
# 20473                     11
# 20940                     11
# 32934                      0
# 40027                      0
# 50520                      0
# 52580                      0
# 54825                      0
# 55095                      0
# 59414                      2
# 133800                     0
# 135337                     0
# 266444                     0

# %%
ispincompliance = lc[lc.asn_id.isin(manrs)].groupby(['asn_id']).agg({'valid_percent':count_incompliance_isp})

# %%
ispincompliance = ispincompliance.reset_index()

# %%
ispincompliance.drop_duplicates()
# Out:
# either_status  originasn_id  valid_percent
# 0                        87              0
# 1                        88              0
# 2                        92              0
# 3                       101              0
# 4                       103              0
# ..                      ...            ...
# 769                  395262              0
# 770                  396955              0
# 771                  396961              0
# 772                  398866              0
# 773                  399214              0
#
# [774 rows x 2 columns]

# %%
ispincompliance[ispincompliance.valid_percent < 90]
# Out:
# either_status  originasn_id  valid_percent
# 0                        87              0
# 1                        88              0
# 2                        92              0
# 3                       101              0
# 4                       103              0
# ..                      ...            ...
# 769                  395262              0
# 770                  396955              0
# 771                  396961              0
# 772                  398866              0
# 773                  399214              0
#
# [774 rows x 2 columns]

# %%
lc[lc.asn_id == 26806]
# Out:
# either_status  originasn_id  valid_percent       date
# 249                   26806           87.5 2022-02-06
# 1031                  26806           87.5 2022-02-13
# 1813                  26806           87.5 2022-02-20
# 2596                  26806           87.5 2022-02-27
# 3380                  26806           87.5 2022-03-06
# 4162                  26806           87.5 2022-03-13
# 4946                  26806           87.5 2022-03-27
# 5708                  26806          100.0 2022-04-10
# 6422                  26806           87.5 2022-04-17
# 7204                  26806           87.5 2022-04-24
# 7985                  26806           87.5 2022-05-01

# %%
plt.plot(np.sort(ispincompliance['valid_percent']), np.linspace(0,1,len(ispincompliance)))
plt.xlabel('# of weeks not compliant')
plt.ylabel('CDF')
plt.ylim(bottom=0.9)
plt.grid()

# %%
manrs_transit[manrs_transit.asn_id == 399214]
# Out:
#                  id                 timebin            prefix  hege  af  \
# 1907535  1414481441  2022-05-01 00:00:00+00  142.202.154.0/24   1.0   4
# 2268820  1414120147  2022-05-01 00:00:00+00    45.42.168.0/23   1.0   4
# 2976898  1413412213  2022-05-01 00:00:00+00    158.51.10.0/24   1.0   4
#
#          visibility rpki_status irr_status delegated_prefix_status  \
# 1907535       100.0       Valid      Valid                assigned
# 2268820       100.0       Valid      Valid                assigned
# 2976898       100.0       Valid      Valid                assigned
#
#         delegated_asn_status  \
# 1907535             assigned
# 2268820             assigned
# 2976898             assigned
#
#                                                      descr moas  asn_id  \
# 1907535  Joust Security Inc.\n925 boul. de Maisonneuve ...    f  399214
# 2268820  The Ministry of Compute Inc.\n925 boul. de Mai...    f  399214
# ...

# %% [markdown]
# earier version: diff 2107 and 2204 snapshots

# %%
ihr2107 = pd.read_csv(ihr[0])
ihr2204 = pd.read_csv(ihr[-1])

# %%
ihr2107_manrs = ihr2107[ihr2107['asn_id'].isin(manrsas)]
ihr2204_manrs = ihr2204[ihr2204['asn_id'].isin(manrsas)]

# %%
ihr2107_manrs['either_status'] = ihr2107_manrs.apply(irr_or_rpki, axis=1)
ihr2204_manrs['either_status'] = ihr2204_manrs.apply(irr_or_rpki, axis=1)
# Out:
# /home/c4du/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
ihr2107_either = ihr2107_manrs.groupby(['asn_id', 'either_status']).size().unstack(fill_value=0).reset_index()
ihr2204_either = ihr2204_manrs.groupby(['asn_id', 'either_status']).size().unstack(fill_value=0).reset_index()

# %%
ihr2107_either['valid_percent'] = ihr2107_either[True]/(ihr2107_either[False] + ihr2107_either[True])*100
ihr2204_either['valid_percent'] = ihr2204_either[True]/(ihr2204_either[False] + ihr2204_either[True])*100

# %%
ihr2107_either
# Out:
# either_status  originasn_id  False  True  valid_percent
# 0                        87      0    19         100.00
# 1                        88      0    12         100.00
# 2                        92      0     5         100.00
# 3                       101      0     8         100.00
# 4                       103      0    23         100.00
# ..                      ...    ...   ...            ...
# 779                  395262      0     2         100.00
# 780                  396955      1    15          93.75
# 781                  396961      0    10         100.00
# 782                  398866      0     1         100.00
# 783                  399214      0     2         100.00
#
# [784 rows x 4 columns]

# %%
ihr2204_either
# Out:
# either_status  originasn_id  False  True  valid_percent
# 0                        87      0    19     100.000000
# 1                        88      0    12     100.000000
# 2                        92      0     5     100.000000
# 3                       101      0     8     100.000000
# 4                       103      0    23     100.000000
# ..                      ...    ...   ...            ...
# 777                  395262      0     2     100.000000
# 778                  396955      1    16      94.117647
# 779                  396961      0    10     100.000000
# 780                  398866      0     2     100.000000
# 781                  399214      0     6     100.000000
#
# [782 rows x 4 columns]

# %%
manrs_range = ihr2107_either.merge(ihr2204_either, on=['asn_id'], how='outer', suffixes=('_2107', '_2204'))

# %%
def delta_valid_percent(x,y):
    if pd.isnull(x)
# Out:
#   File "/tmp/ipykernel_57820/461708672.py", line 2
#     if pd.isnull(x)
#                    ^
# SyntaxError: invalid syntax

# %%
manrs_range['delta_valid'] = manrs_range['valid_percent_2204'] - manrs_range['valid_percent_2107']

# %%
manrs_range

# %%
plt.plot(np.sort(manrs_range.delta_valid), np.linspace(0,1,len(manrs_range.delta_valid)))
