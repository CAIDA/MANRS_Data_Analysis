# %% [markdown]
# # Are MANRS ASes conformant to Action 4?
# MANRS action 4 states that MANRS networks should originate prefixes that are RPKI or IRR valid.
#
# Paper: https://www.caida.org/catalog/papers/2022_mind_your_manrs/mind_your_manrs.pdf

# %%
import pandas as pd
import os
import multiprocessing as mp
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import requests
from collections import defaultdict
from matplotlib.ticker import MaxNLocator
import bz2
import lz4.frame
import urllib
import gzip

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # MANRS ASes
#
# Parse ASes in the MANRS Network Operators Program. CSV files can be downloaded from:
# https://www.manrs.org/netops/participants/

# %%
manrs = []
manrs_org = {}
manrs_org2as = defaultdict(list)
with open('manrs_isps.csv', 'rt') as f:  #replace with new file
    for line in f:
        data = line.strip().split(',')
        if len(data) < 7:
            continue
        asns = data[2].split(';')
        for i in asns:
            try:
                manrs.append(int(i))
                manrs_org[int(i)] = data[0]
                manrs_org2as[data[0]].append(int(i))
            except:
                pass

# %% [markdown]
# Parse ASes in the MANRS CDN and Cloud Provider Program. CSV files can be downloaded from:
# https://www.manrs.org/cdn-cloud-providers/participants/

# %%
manrscdn = []
with open('manrs_cdns.csv', 'rt') as f:   #replace with new file
    for line in f:
        data = line.strip().split(',')
        if len(data) < 7:
            continue
        asns = data[1].split(';')
        for i in asns:
            if not i.isdigit():
                continue
            try:
                manrscdn.append(int(i))
                manrs_org[int(i)] = data[0]
                manrs_org2as[data[0]].append(int(i))
            except:
                pass

# %%
manrscdn
# Out:
# [20940,
#  52580,
#  59414,
#  266444,
#  50520,
#  135337,
#  54825,
#  8280,
#  14061,
#  32934,
#  8075,
#  8074,
#  2906,
#  40027,
#  55095,
#  13335,
#  16509,
#  133800,
#  15169,
#  7342,
#  20473]

# %%
manrsas = manrs + manrscdn

# %%
len(manrs)
# Out:
# 849

# %%
len(manrscdn)
# Out:
# 21

# %% [markdown]
# ## Group by AS size (number of customers)
#
# ### Parse CAIDA AS Relationship Dataset
#
# CAIDA AS Relationship Dataset can be downloaded from:
# https://www.caida.org/catalog/datasets/as-relationships/
# Use files with the extension `.as-rel.txt.bz2`

# %%
path = '20220301.as-rel.txt.bz2'   #replace with new file
as_cust = defaultdict(int)
with bz2.open(path, 'rt') as file:
    for line in file:
        if line.startswith('#'):
            continue
        data = line.strip().split('|')
        AS1 = int(data[0])
        AS2 = int(data[1])
        rel = data[2]
        if rel == '1':
            as_cust[AS2] += 1
        elif rel == '-1':
            as_cust[AS1] += 1

# %%
cust_deg = pd.DataFrame(as_cust.items(), columns=['asn', 'cust'])

# %%
small = cust_deg[cust_deg.cust <= 2]['asn']
medium = cust_deg[(cust_deg.cust > 2) & (cust_deg.cust < 180)]['asn']
large = cust_deg[cust_deg.cust >= 180]['asn']

# %%
cust_deg
# Out:
#           asn  what  cust  provider  peer
# 0      136808   NaN     0         2     0
# 1      201786   NaN     0         2     0
# 2       34289   NaN     0         1     0
# 3      328605   NaN     6         2     0
# 4       20257   NaN     1         1     0
# ...       ...   ...   ...       ...   ...
# 73747   11960   NaN     2         6     0
# 73748   23338   NaN     1         1     0
# 73749   46738   NaN     1         2     0
# 73750  138869   NaN     0         1     0
# 73751   28576   NaN     1         2    22
#
# [73752 rows x 5 columns]

# %% [markdown]
# ### separate MANRS and non-MANRS ASes into small, medium, and large catgories
#
# small ASes have # of customers < 2
# medium ASes have # of customers between 2 and 180
# Large ASes have # of customers > 180

# %%
medium_manrs = set(manrsas).intersection(set(medium))
large_manrs = set(manrsas).intersection(set(large))
small_manrs = set(manrsas) - medium_manrs - large_manrs

# %%
print(len(small_manrs), len(medium_manrs), len(large_manrs))
# Out:
# 520 319 24

# %%
small_non_manrs = set(small) - small_manrs
medium_non_manrs = set(medium) - medium_manrs
large_non_manrs = set(large) - large_manrs

# %% [markdown]
# # RPKI and IRR statuses of prefixes originated by MANRS and non-MANRS networks
#
# ## Process data from the Internet Health Report
# IHR data can be downloaded from:
# https://ihr-archive.iijlab.net/ihr/rov/
#
# IHR also provides a dashboard:
# https://ihr.iijlab.net/ihr/en-us/rov

# %%
ihrurl = 'https://ihr-archive.iijlab.net/ihr/rov/2022/05/01/ihr_rov_2022-05-01.csv.lz4' #replace with new file

# %%
def process_ihr(url):
    try:
        handle = urllib.request.urlopen(url)
    except:
        print('URL not found', url)
        raise Exception
        return
    with lz4.frame.open(handle) as f:
        df = pd.read_csv(f)
        origindf = df[df.asn_id == df.originasn_id]
        return origindf

# %%
origindf = process_ihr(ihrurl)

# %%
origindf = origindf[origindf.af == 4]

# %%
origindf
# Out:
#                  id                 timebin            prefix      hege  af  \
# 691982   1415697055  2022-05-01 00:00:00+00   165.156.17.0/24  0.027211   4
# 691984   1415697053  2022-05-01 00:00:00+00  156.154.101.0/24  0.027211   4
# 691986   1415697051  2022-05-01 00:00:00+00      64.6.65.0/24  0.040816   4
# 691988   1415697049  2022-05-01 00:00:00+00   156.154.64.0/24  0.040816   4
# 691990   1415697047  2022-05-01 00:00:00+00   204.74.112.0/24  0.040816   4
# ...             ...                     ...               ...       ...  ..
# 5294722  1411094442  2022-05-01 00:00:00+00       1.6.73.0/24  1.000000   4
# 5294723  1411094441  2022-05-01 00:00:00+00       1.32.0.0/19  1.000000   4
# 5294724  1411094440  2022-05-01 00:00:00+00       1.72.0.0/23  1.000000   4
# 5294725  1411094439  2022-05-01 00:00:00+00      1.66.90.0/24  1.000000   4
# 5294726  1411094438  2022-05-01 00:00:00+00      1.6.164.0/22  1.000000   4
#
#          visibility rpki_status irr_status delegated_prefix_status  \
# 691982    11.475410    NotFound      Valid                assigned
# 691984    11.475410    NotFound      Valid                assigned
# 691986    12.568306    NotFound      Valid                assigned
# 691988    12.568306    NotFound      Valid                assigned
# 691990    12.568306    NotFound      Valid                assigned
# ...             ...         ...        ...                     ...
# 5294722   99.453552       Valid      Valid                assigned
# 5294723   98.907104       Valid      Valid                assigned
# 5294724   99.453552    NotFound      Valid                assigned
# 5294725   99.453552    NotFound      Valid                assigned
# 5294726   98.907104       Valid      Valid                assigned
#
#         delegated_asn_status  \
# 691982              assigned
# 691984              assigned
# 691986              assigned
# 691988              assigned
# 691990              assigned
# ...                      ...
# 5294722             assigned
# 5294723             assigned
# 5294724             assigned
# 5294725             assigned
# 5294726             assigned
#
#                                                      descr moas  asn_id  \
# 691982                                             Neustar    t  397224
# 691984                                             Neustar    t  397224
# 691986                                             Neustar    t  397224
# 691988                                             Neustar    t  397224
# 691990                                             Neustar    t  397224
# ...                                                    ...  ...     ...
# 5294722                              Sify IP address space    f    9583
# 5294723  Telekom Malaysia Berhad\nCore IP & NGN\n17th F...    f    4788
# 5294724                         NTT DoCoMo, Inc. expire=24    f    9605
# 5294725                         NTT DoCoMo, Inc. expire=24    f    9605
# 5294726                              Sify IP address space    f    9583
#
#         country_id  originasn_id
# 691982          US        397224
# 691984          US        397224
# 691986          US        397224
# 691988          US        397224
# 691990          US        397224
# ...            ...           ...
# 5294722         IN          9583
# 5294723         MY          4788
# 5294724         JP          9605
# 5294725         JP          9605
# 5294726         IN          9583
#
# [925224 rows x 15 columns]

# %%
manrs_origin = origindf[origindf.originasn_id.isin(manrsas)]
non_manrs_origin = origindf[~origindf.originasn_id.isin(manrsas)]

# %%
manrs_origin['nettype'] = manrs_origin['originasn_id'].apply(lambda x: 'CDN' if x in manrscdn else 'ISP')
# Out:
# /home/c4du/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
small_manrs_origin = manrs_origin[manrs_origin.originasn_id.isin(small)]
medium_manrs_origin = manrs_origin[manrs_origin.originasn_id.isin(medium)]
large_manrs_origin = manrs_origin[manrs_origin.originasn_id.isin(large)]

# %%
small_non_manrs_origin = non_manrs_origin[non_manrs_origin.originasn_id.isin(small)]
medium_non_manrs_origin = non_manrs_origin[non_manrs_origin.originasn_id.isin(medium)]
large_non_manrs_origin = non_manrs_origin[non_manrs_origin.originasn_id.isin(large)]

# %% [markdown]
# ## RPKI: Check if announced prefixes are RPKI valid

# %%
manrs_origin_rpki = manrs_origin.groupby(['originasn_id', 'rpki_status']).size().unstack(fill_value=0).reset_index()
manrs_origin_rpki['rpki_percent'] = (1-manrs_origin_rpki['NotFound']/manrs_origin_rpki[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1))*100

# %%
non_manrs_origin_rpki = non_manrs_origin.groupby(['originasn_id', 'rpki_status']).size().unstack(fill_value=0).reset_index()
non_manrs_origin_rpki['rpki_percent'] = (1-non_manrs_origin_rpki['NotFound']/non_manrs_origin_rpki[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1))*100

# %%
small_manrs_origin_rpki = manrs_origin_rpki[manrs_origin_rpki.originasn_id.isin(small)]
medium_manrs_origin_rpki = manrs_origin_rpki[manrs_origin_rpki.originasn_id.isin(medium)]
large_manrs_origin_rpki = manrs_origin_rpki[manrs_origin_rpki.originasn_id.isin(large)]

# %%
small_non_manrs_origin_rpki = non_manrs_origin_rpki[non_manrs_origin_rpki.originasn_id.isin(small)]
medium_non_manrs_origin_rpki = non_manrs_origin_rpki[non_manrs_origin_rpki.originasn_id.isin(medium)]
large_non_manrs_origin_rpki = non_manrs_origin_rpki[non_manrs_origin_rpki.originasn_id.isin(large)]

# %% [markdown]
# ### Are MANRS ASes more likely to originate RPKI valid prefixes than non_MANRS ASes?
#
# The code snippet corresponds to figure 5(a) in the paper

# %%
manrs_origin_rpki['valid_percent'] = (manrs_origin_rpki['Valid']/manrs_origin_rpki[['Invalid','Invalid,more-specific','Valid', 'NotFound']].sum(axis=1))*100
non_manrs_origin_rpki['valid_percent'] = (non_manrs_origin_rpki['Valid']/non_manrs_origin_rpki[['Invalid','Invalid,more-specific','Valid', 'NotFound']].sum(axis=1))*100

# %%
small_manrs_origin_rpki['valid_percent'] = (small_manrs_origin_rpki['Valid']/small_manrs_origin_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
small_non_manrs_origin_rpki['valid_percent'] = (small_non_manrs_origin_rpki['Valid']/small_non_manrs_origin_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

medium_manrs_origin_rpki['valid_percent'] = (medium_manrs_origin_rpki['Valid']/medium_manrs_origin_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
medium_non_manrs_origin_rpki['valid_percent'] = (medium_non_manrs_origin_rpki['Valid']/medium_non_manrs_origin_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

large_manrs_origin_rpki['valid_percent'] = (large_manrs_origin_rpki['Valid']/large_manrs_origin_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
large_non_manrs_origin_rpki['valid_percent'] = (large_non_manrs_origin_rpki['Valid']/large_non_manrs_origin_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

# %%
plt.figure(figsize=(8,6))
plt.plot(np.sort(small_manrs_origin_rpki['valid_percent']), np.linspace(0,1,len(small_manrs_origin_rpki)), label='small MANRS', linestyle='-')
plt.plot(np.sort(small_non_manrs_origin_rpki['valid_percent']), np.linspace(0,1,len(small_non_manrs_origin_rpki)), label='small non-MANRS', linestyle='-')
plt.plot(np.sort(medium_manrs_origin_rpki['valid_percent']), np.linspace(0,1,len(medium_manrs_origin_rpki)), label='medium MANRS', linestyle='--')
plt.plot(np.sort(medium_non_manrs_origin_rpki['valid_percent']), np.linspace(0,1,len(medium_non_manrs_origin_rpki)), label='medium non-MANRS', linestyle='--')
plt.plot(np.sort(large_manrs_origin_rpki['valid_percent']), np.linspace(0,1,len(large_manrs_origin_rpki)), label='large MANRS', linestyle='-.')
plt.plot(np.sort(large_non_manrs_origin_rpki['valid_percent']), np.linspace(0,1,len(large_non_manrs_origin_rpki)), label='large non-MANRS', linestyle='-.')
plt.xlabel('Percent of Originated RPKI Valid Prefixes', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(80, 105)
plt.legend(loc=2)
plt.grid()

# %% [markdown]
# ### Spot check: which ASes originated no RPKI valid prefixes?
#
# #### Parse CAIDA as2org dataset
# CAIDA as2org dataset can be downloaded from:
# https://www.caida.org/catalog/datasets/as-organizations/
#
# The code below maps AS numbers to organization names

# %%
path = '20220401.as-org2info.txt.gz'   #replace with new file
mapping = {}
companyname = {}
org2as = defaultdict(list)

with gzip.open(path, 'rt') as as2org:
    for line in as2org:
        l = line.strip('\n').split('|')
        asn = None
        if l[0].isdigit():
            asn = l[0]
            mapping[int(asn)] = l[3]
        elif len(l) == 5:
            companyname[l[0]] = (l[2], l[3])
    for i in mapping:
        orgname = companyname[mapping[i]]
        mapping[i] = orgname
        org2as[orgname].append(i)

# %%
large_non_manrs_origin_rpki['company'] = large_non_manrs_origin_rpki['originasn_id'].apply(lambda x: mapping[x] if x in mapping else None)
# Out:
# /home/c4du/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# #### **Only non-MANRS ASes originate no RPKI valid prefixes**

# %%
large_non_manrs_origin_rpki[large_non_manrs_origin_rpki.valid_percent == 0]
# Out:
# rpki_status  originasn_id  Invalid  Invalid,more-specific  NotFound  Valid  \
# 235                   577        0                      0       675      0
# 917                  2828        0                      0       112      0
# 1028                 3216        0                      0       788      0
# 1054                 3255        0                      0       316      0
# 2764                 8167        0                      0       340      0
# 3422                 9318        0                      0       643      0
# 11947               23106        0                      0        31      0
# 12492               23947        2                      0         9      0
# 15696               29076        0                      0        56      0
# 15791               29226        0                      0        17      0
# 38161               61832        0                      0        10      0
#
# rpki_status  rpki_percent  valid_percent  \
# 235              0.000000            0.0
# 917              0.000000            0.0
# 1028             0.000000            0.0
# 1054             0.000000            0.0
# 2764             0.000000            0.0
# 3422             0.000000            0.0
# 11947            0.000000            0.0
# 12492           18.181818            0.0
# 15696            0.000000            0.0
# 15791            0.000000            0.0
# 38161            0.000000            0.0
#
# rpki_status                                            company  totalPO
# 235                                          (Bell Canada, CA)      675
# 917                                     (Verizon Business, US)      112
# 1028                                    (PJSC "Vimpelcom", RU)      788
# 1054         (State Enterprise Scientific and Telecommunica...      316
# 2764           (BRASIL TELECOM COMUNICACAO MULTIMIDIA S.A, BR)      340
# 3422                                 (SK Broadband Co Ltd, KR)      643
# 11947        (AMERICAN TOWER DO BRASIL-COMUNICAÇÂO MULTIMÍD...       31
# 12492                       (PT.Mora Telematika Indonesia, ID)       11
# 15696                                        (Filanco LLC, RU)       56
# 15791                                      (JSC Mastertel, RU)       17
# 38161             (Fortel Fortaleza Telecomunicacoes Ltda, BR)       10

# %%
large_non_manrs_origin_rpki[large_non_manrs_origin_rpki.valid_percent == 100]
# Out:
# rpki_status  originasn_id  Invalid  Invalid,more-specific  NotFound  Valid  \
# 10411               20764        0                      0         0      5
# 30285               50607        0                      0         0      2
# 36101               58717        0                      0         0     32
# 38362               62081        0                      0         0      1
# 50345              201054        0                      0         0      1
#
# rpki_status  rpki_percent  valid_percent                             company
# 10411               100.0          100.0                   (CJSC RASCOM, RU)
# 30285               100.0          100.0     (Stowarzyszenie e-Poludnie, PL)
# 36101               100.0          100.0  (Summit Communication Limited, BD)
# 38362               100.0          100.0     (Stowarzyszenie e-Poludnie, PL)
# 50345               100.0          100.0     (Stowarzyszenie e-Poludnie, PL)

# %%
large_manrs_origin_rpki['totalPO'] = large_manrs_origin_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1)
large_non_manrs_origin_rpki['totalPO'] = large_non_manrs_origin_rpki[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1)
# Out:
# /home/c4du/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# ### How many RPKI valids, invalids do each type of networks originate?

# %% [markdown]
# #### medium MANRS networks that originated RPKI invalid prefixes

# %%
med_invalid_ASN = medium_manrs_origin_rpki[medium_manrs_origin_rpki.Invalid > 0]['originasn_id']
for i in med_invalid_ASN:
    try:
        print(i, manrs_org[int(i)])
    except:
        print(i)
# Out:
# 10021 Colt Technology Services
# 16509 Amazon Web Services
# 20940 Akamai Technologies
# 23688 Link3 Technologies Ltd.
# 33659 Comcast
# 52468 Ufinet

# %%
manrs_origin[manrs_origin.originasn_id.isin(med_invalid_ASN) & (manrs_origin.rpki_status == 'Invalid')]
# Out:
#                  id                 timebin            prefix      hege  af  \
# 705730   1415683351  2022-05-01 00:00:00+00   200.60.190.0/24  0.360544   4
# 705744   1415683337  2022-05-01 00:00:00+00   200.60.136.0/23  0.360544   4
# 1525613  1414863520  2022-05-01 00:00:00+00    154.215.1.0/24  0.115646   4
# 1539864  1414849266  2022-05-01 00:00:00+00  130.156.192.0/20  0.346939   4
# 1968948  1414420163  2022-05-01 00:00:00+00    103.9.104.0/24  0.639456   4
# 1969760  1414419749  2022-05-01 00:00:00+00    170.82.39.0/24  0.646259   4
# 2120580  1414267989  2022-05-01 00:00:00+00    103.9.104.0/23  0.639456   4
# 3484956  1412903885  2022-05-01 00:00:00+00   200.60.136.0/24  0.360544   4
# 3486203  1412903306  2022-05-01 00:00:00+00   158.51.108.0/24  0.489796   4
# 3494986  1412893665  2022-05-01 00:00:00+00    103.9.105.0/24  0.639456   4
#
#          visibility rpki_status irr_status delegated_prefix_status  \
# 705730    36.065574     Invalid    Invalid                assigned
# 705744    36.065574     Invalid    Invalid                assigned
# 1525613   16.939891     Invalid      Valid                assigned
# 1539864   34.972678     Invalid    Invalid                assigned
# 1968948   50.819672     Invalid    Invalid                assigned
# 1969760   50.819672     Invalid      Valid                assigned
# 2120580   50.819672     Invalid    Invalid                assigned
# 3484956   36.065574     Invalid    Invalid                assigned
# 3486203   40.983607     Invalid      Valid                assigned
# 3494986   50.819672     Invalid    Invalid                assigned
#
#         delegated_asn_status  \
# 705730              assigned
# 705744              assigned
# 1525613             assigned
# 1539864             assigned
# 1968948             assigned
# 1969760             assigned
# 2120580             assigned
# 3484956             assigned
# 3486203             assigned
# 3494986             assigned
#
#                                                      descr moas  asn_id  \
# 705730                       Proxy-registered route object    f   20940
# 705744   UniRed - Infointernet - RED_36\nTelefonica Dat...    f   20940
# 1525613                                       funglr, Inc.    f   10021
# 1539864  NJEDge.Net INC\n625 Broad Street, Suite 260\nN...    f   33659
# 1968948                    route object for 103.9.104.0/24    f   23688
# 1969760                                UFINET HONDURAS S.A    t   52468
# 2120580                    route object for 103.9.104.0/23    f   23688
# 3484956  UniRed - Infointernet - RED_36\nTelefonica Dat...    f   20940
# 3486203                                  Amazon EC2 Prefix    f   16509
# 3494986                    route object for 103.9.105.0/24    f   23688
#
#         country_id  originasn_id nettype
# 705730          PE         20940     CDN
# 705744          PE         20940     CDN
# 1525613         HK         10021     ISP
# 1539864         US         33659     ISP
# 1968948         BD         23688     ISP
# 1969760         HN         52468     ISP
# 2120580         BD         23688     ISP
# 3484956         PE         20940     CDN
# 3486203         US         16509     CDN
# 3494986         BD         23688     ISP

# %% [markdown]
# #### medium MANRS networks that originated RPKI Invalid Prefix Length prefixes

# %%
med_invalid_len = medium_manrs_origin_rpki[medium_manrs_origin_rpki['Invalid,more-specific'] > 0]['originasn_id']
for i in med_invalid_len:
    try:
        print(i, manrs_org[int(i)])
    except:
        print(i)
# Out:
# 23674 Nayatel Pvt. Ltd
# 28294 Univox
# 48362 Stadtwerke Feldkirch

# %%
manrs_origin[manrs_origin.originasn_id.isin(med_invalid_len) & (manrs_origin.rpki_status == 'Invalid,more-specific')]
# Out:
#                  id                 timebin            prefix      hege  af  \
# 718348   1415670555  2022-05-01 00:00:00+00    92.249.22.0/24  0.034014   4
# 1526355  1414862791  2022-05-01 00:00:00+00    101.50.84.0/22  0.387755   4
# 1549420  1414839426  2022-05-01 00:00:00+00  179.107.208.0/21  0.435374   4
# 1963005  1414426153  2022-05-01 00:00:00+00    92.249.20.0/24  0.034014   4
#
#          visibility            rpki_status             irr_status  \
# 718348    11.475410  Invalid,more-specific  Invalid,more-specific
# 1526355   36.612022  Invalid,more-specific  Invalid,more-specific
# 1549420   40.983607  Invalid,more-specific                  Valid
# 1963005   11.475410  Invalid,more-specific  Invalid,more-specific
#
#         delegated_prefix_status delegated_asn_status  \
# 718348                 assigned             assigned
# 1526355                assigned             assigned
# 1549420                assigned             assigned
# 1963005                assigned             assigned
#
#                                        descr moas  asn_id country_id  \
# 718348                                   NaN    f   48362         AT
# 1526355  Nayatel Route Object 101.50.64.0/18    f   23674         PK
# 1549420                               Univox    f   28294         BR
# 1963005                                  NaN    f   48362         AT
#
#          originasn_id nettype
# 718348          48362     ISP
# 1526355         23674     ISP
# 1549420         28294     ISP
# 1963005         48362     ISP

# %% [markdown]
# #### large MANRS networks that originated RPKI Invalid prefixes

# %%
large_invalid_ASN = large_manrs_origin_rpki[large_manrs_origin_rpki.Invalid > 0]['originasn_id']
for i in large_invalid_ASN:
    try:
        print(i, manrs_org[int(i)])
    except:
        print(i)
# Out:
# 174 Cogent Communications Inc.
# 3356 CenturyLink
# 3549 CenturyLink
# 13335 Cloudflare
# 20115 Charter Communications

# %%
manrs_origin[manrs_origin.originasn_id.isin(large_invalid_ASN) & (manrs_origin.rpki_status == 'Invalid')]
# Out:
#                  id                 timebin            prefix      hege  af  \
# 699120   1415689926  2022-05-01 00:00:00+00  178.171.100.0/24  0.632653   4
# 717770   1415671250  2022-05-01 00:00:00+00   212.69.135.0/24  0.061224   4
# 719522   1415669945  2022-05-01 00:00:00+00   45.172.187.0/24  0.210884   4
# 1545909  1414843588  2022-05-01 00:00:00+00    45.84.242.0/24  0.632653   4
# 1557276  1414831811  2022-05-01 00:00:00+00   216.173.83.0/24  0.061224   4
# 2114870  1414274639  2022-05-01 00:00:00+00    98.154.77.0/24  0.006803   4
# 2121627  1414268231  2022-05-01 00:00:00+00    85.239.55.0/24  0.700680   4
# 2121642  1414268216  2022-05-01 00:00:00+00    45.84.243.0/24  0.632653   4
# 4346576  1412042289  2022-05-01 00:00:00+00   103.21.244.0/24  0.687075   4
# 4537577  1411851404  2022-05-01 00:00:00+00     47.19.10.0/24  0.646259   4
# 5189951  1411199558  2022-05-01 00:00:00+00   173.241.94.0/24  0.646259   4
# 5196322  1411192703  2022-05-01 00:00:00+00    83.147.52.0/22  0.625850   4
#
#          visibility rpki_status             irr_status  \
# 699120    51.366120     Invalid                Invalid
# 717770    13.661202     Invalid                Invalid
# 719522    24.590164     Invalid                Invalid
# 1545909   51.366120     Invalid                Invalid
# 1557276   14.207650     Invalid                Invalid
# 2114870    8.743169     Invalid                Invalid
# 2121627   56.830601     Invalid                Invalid
# 2121642   51.366120     Invalid                Invalid
# 4346576   56.284153     Invalid  Invalid,more-specific
# 4537577   52.459016     Invalid                Invalid
# 5189951   52.459016     Invalid               NotFound
# 5196322   49.180328     Invalid                  Valid
#
#         delegated_prefix_status delegated_asn_status  \
# 699120                 assigned             assigned
# 717770                 assigned             assigned
# 719522                 assigned             assigned
# 1545909                assigned             assigned
# 1557276                assigned             assigned
# 2114870                assigned             assigned
# 2121627                assigned             assigned
# 2121642                assigned             assigned
# 4346576                assigned             assigned
# 4537577                assigned             assigned
# 5189951                assigned             assigned
# 5196322                assigned             assigned
#
#                                                      descr moas  asn_id  \
# 699120                                                 NaN    f     174
# 717770                                                 NaN    t     174
# 719522                                                 NaN    f    3549
# 1545909                                                NaN    f     174
# 1557276                               H4Y Technologies LLC    t     174
# 2114870                                           RR-Route    t   20115
# 2121627                                                NaN    f     174
# 2121642                                                NaN    f     174
# 4346576     Cloudflare Hong Kong, LLC\n101 Townsend Street    f   13335
# 4537577  BayNetworks\nNortelNetworks\n4401 Great Americ...    f     174
# 5189951                                                NaN    f     174
# 5196322                                                NaN    f    3356
#
#         country_id  originasn_id nettype
# 699120          GB           174     ISP
# 717770          TR           174     ISP
# 719522          CO          3549     ISP
# 1545909         US           174     ISP
# 1557276         US           174     ISP
# 2114870         US         20115     ISP
# 2121627         RU           174     ISP
# 2121642         US           174     ISP
# 4346576         US         13335     CDN
# 4537577         US           174     ISP
# 5189951         US           174     ISP
# 5196322         US          3356     ISP

# %%
large_invalid_len = large_manrs_origin_rpki[large_manrs_origin_rpki['Invalid,more-specific'] > 0]['originasn_id']
for i in large_invalid_len:
    try:
        print(i, manrs_org[int(i)])
    except:
        print(i)
# Out:
# 13335 Cloudflare

# %%
manrs_origin[manrs_origin.originasn_id.isin(large_invalid_len) & (manrs_origin.rpki_status == 'Invalid,more-specific')]
# Out:
#                  id                 timebin          prefix      hege  af  \
# 1963043  1414426058  2022-05-01 00:00:00+00  172.68.83.0/24  0.129252   4
#
#          visibility            rpki_status             irr_status  \
# 1963043   18.579235  Invalid,more-specific  Invalid,more-specific
#
#         delegated_prefix_status delegated_asn_status  \
# 1963043                assigned             assigned
#
#                                                      descr moas  asn_id  \
# 1963043  101 Townsend Street, San Francisco, California...    f   13335
#
#         country_id  originasn_id nettype
# 1963043         US         13335     CDN

# %% [markdown]
# ## IRR: Check if announced prefixes are IRR valid

# %%
manrs_origin_irr = manrs_origin.groupby(['originasn_id', 'irr_status']).size().unstack(fill_value=0).reset_index()
manrs_origin_irr['irr_percent'] = (1-manrs_origin_irr['NotFound']/manrs_origin_irr[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1))*100

# %%
non_manrs_origin_irr = non_manrs_origin.groupby(['originasn_id', 'irr_status']).size().unstack(fill_value=0).reset_index()
non_manrs_origin_irr['irr_percent'] = (1-non_manrs_origin_irr['NotFound']/non_manrs_origin_irr[['Invalid', 'Invalid,more-specific', 'Valid', 'NotFound']].sum(axis=1))*100

# %%
small_manrs_origin_irr = manrs_origin_irr[manrs_origin_irr.originasn_id.isin(small)]
medium_manrs_origin_irr = manrs_origin_irr[manrs_origin_irr.originasn_id.isin(medium)]
large_manrs_origin_irr = manrs_origin_irr[manrs_origin_irr.originasn_id.isin(large)]
small_non_manrs_origin_irr = non_manrs_origin_irr[non_manrs_origin_irr.originasn_id.isin(small)]
medium_non_manrs_origin_irr = non_manrs_origin_irr[non_manrs_origin_irr.originasn_id.isin(medium)]
large_non_manrs_origin_irr = non_manrs_origin_irr[non_manrs_origin_irr.originasn_id.isin(large)]

# %% [markdown]
# ### Are MANRS ASes more likely to originate IRR valid prefixes than non_MANRS ASes?
#
# The code snippet corresponds to figure 5(b) in the paper

# %%
manrs_origin_irr['valid_percent'] = (manrs_origin_irr['Valid']/manrs_origin_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
non_manrs_origin_irr['valid_percent'] = (non_manrs_origin_irr['Valid']/non_manrs_origin_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

# %%
small_manrs_origin_irr['valid_percent'] = (small_manrs_origin_irr['Valid']/small_manrs_origin_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
small_non_manrs_origin_irr['valid_percent'] = (small_non_manrs_origin_irr['Valid']/small_non_manrs_origin_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

medium_manrs_origin_irr['valid_percent'] = (medium_manrs_origin_irr['Valid']/medium_manrs_origin_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
medium_non_manrs_origin_irr['valid_percent'] = (medium_non_manrs_origin_irr['Valid']/medium_non_manrs_origin_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100

large_manrs_origin_irr['valid_percent'] = (large_manrs_origin_irr['Valid']/large_manrs_origin_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
large_non_manrs_origin_irr['valid_percent'] = (large_non_manrs_origin_irr['Valid']/large_non_manrs_origin_irr[['NotFound','Invalid','Invalid,more-specific','Valid']].sum(axis=1))*100
# Out:
# /home/c4du/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
print(len(small_manrs), len(medium_manrs), len(large_manrs))
# Out:
# 520 319 24

# %%
print(len(small_non_manrs), len(medium_non_manrs), len(large_non_manrs))
# Out:
# 68383 4489 86

# %%
plt.figure(figsize=(8,6))
plt.plot(np.sort(small_manrs_origin_irr['valid_percent']), np.linspace(0,1,len(small_manrs_origin_irr)), label='small MANRS ({})'.format(len(small_manrs_origin_irr)), linestyle='-')
plt.plot(np.sort(small_non_manrs_origin_irr['valid_percent']), np.linspace(0,1,len(small_non_manrs_origin_irr)), label='small non-MANRS ({})'.format(len(small_non_manrs_origin_irr)), linestyle='-')
plt.plot(np.sort(medium_manrs_origin_irr['valid_percent']), np.linspace(0,1,len(medium_manrs_origin_irr)), label='medium MANRS ({})'.format(len(medium_manrs_origin_irr)), linestyle='--')
plt.plot(np.sort(medium_non_manrs_origin_irr['valid_percent']), np.linspace(0,1,len(medium_non_manrs_origin_irr)), label='medium non-MANRS ({})'.format(len(medium_non_manrs_origin_irr)), linestyle='--')
plt.plot(np.sort(large_manrs_origin_irr['valid_percent']), np.linspace(0,1,len(large_manrs_origin_irr)), label='large MANRS ({})'.format(len(large_manrs_origin_irr)), linestyle='-.')
plt.plot(np.sort(large_non_manrs_origin_irr['valid_percent']), np.linspace(0,1,len(large_non_manrs_origin_irr)), label='large non-MANRS ({})'.format(len(large_non_manrs_origin_irr)), linestyle='-.')
plt.xlabel('Percent of originated IRR Valid Prefixes', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size':11})
plt.grid()

# %% [markdown]
# ## MANRS ASes that register only in IRR but not in RPKI

# %%
small_manrs_irr_only = small_manrs_origin_irr[['originasn_id','irr_percent']].merge(small_manrs_origin_rpki[['originasn_id','rpki_percent','valid_percent']])
small_non_manrs_irr_only = small_non_manrs_origin_irr[['originasn_id','irr_percent']].merge(small_non_manrs_origin_rpki[['originasn_id','rpki_percent','valid_percent']])


medium_manrs_irr_only = medium_manrs_origin_irr[['originasn_id','irr_percent']].merge(medium_manrs_origin_rpki[['originasn_id','rpki_percent','valid_percent']])
medium_non_manrs_irr_only = medium_non_manrs_origin_irr[['originasn_id','irr_percent']].merge(medium_non_manrs_origin_rpki[['originasn_id','rpki_percent','valid_percent']])


large_manrs_irr_only = large_manrs_origin_irr[['originasn_id','irr_percent']].merge(large_manrs_origin_rpki[['originasn_id','rpki_percent','valid_percent']])
large_non_manrs_irr_only = large_non_manrs_origin_irr[['originasn_id','irr_percent']].merge(large_non_manrs_origin_rpki[['originasn_id','rpki_percent','valid_percent']])

# %%
small_manrs_irr_only[(small_manrs_irr_only.irr_percent > 0) & (small_manrs_irr_only.rpki_percent == 0)]
# Out:
#      originasn_id  irr_percent  rpki_percent  valid_percent
# 3             103        100.0           0.0            0.0
# 4             111        100.0           0.0            0.0
# 5             160        100.0           0.0            0.0
# 21           5503        100.0           0.0            0.0
# 22           6509        100.0           0.0            0.0
# ..            ...          ...           ...            ...
# 416        328259        100.0           0.0            0.0
# 418        328271        100.0           0.0            0.0
# 422        328582        100.0           0.0            0.0
# 426        394989        100.0           0.0            0.0
# 431        398866        100.0           0.0            0.0
#
# [102 rows x 4 columns]

# %%
medium_manrs_irr_only[(medium_manrs_irr_only.irr_percent > 0) & (medium_manrs_irr_only.rpki_percent == 0)]
# Out:
#      originasn_id  irr_percent  rpki_percent  valid_percent
# 3             271   100.000000           0.0            0.0
# 4             293   100.000000           0.0            0.0
# 7             557   100.000000           0.0            0.0
# 22           2572   100.000000           0.0            0.0
# 34           4538    99.930955           0.0            0.0
# 48           7342   100.000000           0.0            0.0
# 56           7850   100.000000           0.0            0.0
# 75          10886   100.000000           0.0            0.0
# 84          11714   100.000000           0.0            0.0
# 98          14041   100.000000           0.0            0.0
# 101         14325   100.000000           0.0            0.0
# 103         14877   100.000000           0.0            0.0
# 109         15706   100.000000           0.0            0.0
# 115         19782   100.000000           0.0            0.0
# 119         20928   100.000000           0.0            0.0
# 140         25818   100.000000           0.0            0.0
# 142         26806    85.714286           0.0            0.0
# 150         28130   100.000000           0.0            0.0
# 151         28140   100.000000           0.0            0.0
# 153         28169   100.000000           0.0            0.0
# 160         28666   100.000000           0.0            0.0
# 165         30985   100.000000           0.0            0.0
# 183         33666   100.000000           0.0            0.0
# 196         37125   100.000000           0.0            0.0
# 198         37282   100.000000           0.0            0.0
# 199         37457   100.000000           0.0            0.0
# 200         37697   100.000000           0.0            0.0
# 205         38794   100.000000           0.0            0.0
# 214         43404   100.000000           0.0            0.0
# 221         45796   100.000000           0.0            0.0
# 228         50265   100.000000           0.0            0.0
# 240         53152   100.000000           0.0            0.0
# 241         53167   100.000000           0.0            0.0
# 259         61785   100.000000           0.0            0.0
# 278        262880   100.000000           0.0            0.0
# 281        263047   100.000000           0.0            0.0
# 285        263462   100.000000           0.0            0.0
# 287        263616   100.000000           0.0            0.0
# 289        263959   100.000000           0.0            0.0
# 294        265066   100.000000           0.0            0.0
# 299        265950   100.000000           0.0            0.0
# 300        266013   100.000000           0.0            0.0
# 303        266388   100.000000           0.0            0.0
# 306        266525   100.000000           0.0            0.0
# 307        266968   100.000000           0.0            0.0
# 308        267562   100.000000           0.0            0.0

# %%
large_manrs_irr_only[(large_manrs_irr_only.irr_percent > 0) & (large_manrs_irr_only.rpki_percent == 0)]
# Out:
# Empty DataFrame
# Columns: [originasn_id, irr_percent, rpki_percent, valid_percent]
# Index: []

# %% [markdown]
# # **MANRS Action 4 Conformance**
# Conformance analysis is separate for ASes in the MANRS Network Operators Program and MANRS CDN Program

# %%
def irr_or_rpki(r):
    if r['irr_status'] == 'Valid' or r['rpki_status'] == 'Valid' or r['irr_status'] == 'Invalid,more-specific':
        return True
    return False

# %%
manrs_origin['either_status'] = manrs_origin.apply(irr_or_rpki, axis=1)
# Out:
# /home/c4du/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
non_manrs_origin['either_status'] = non_manrs_origin.apply(irr_or_rpki, axis=1)

# %%
manrs_origin_either = manrs_origin.groupby(['originasn_id', 'either_status']).size().unstack(fill_value=0).reset_index()

# %%
non_manrs_origin_either = non_manrs_origin.groupby(['originasn_id', 'either_status']).size().unstack(fill_value=0).reset_index()

# %% [markdown]
# ## Terminology: Explanation of column names
# `either_status`: Index of each row
# `originasn_id`: A MANRS AS
# `False`: Number of prefixes announced by the `originasn_id` that is neither RPKI valid nor IRR valid
# `True`: Number of prefixes announnced by the `originasn_id` that is either RPKI valid or IRR valid

# %%
manrs_origin_either[manrs_origin_either[False] > 0]
# Out:
# either_status  originasn_id  False  True
# 8                       174   1283  2231
# 11                      278      3   143
# 13                      376     10   177
# 14                      553      5    92
# 18                      680      2   284
# 20                     1103      1    98
# 23                     1221    146   214
# 25                     1299      4   132
# 27                     1653      3    49
# 30                     1916      2   160
# 44                     2614      1    98
# 47                     2914      2   231
# 50                     3292      7   143
# 53                     3356    439   268
# 55                     3549    719    53
# 61                     4134      3   754
# 63                     4538      4  4341
# 65                     4764      5   448
# 67                     4809      1   289
# 73                     5511      9    69
# 75                     5607      4    31
# 78                     6461    177    28
# 82                     7015     45    59
# 83                     7016     13    38
# 90                     7725      5    36
# 93                     7843      5   142
# 94                     7850      1    24
# 98                     7922     94   220
# 113                    9002      1    41
# 119                    9541      3   566
# 124                   10796      5   668
# 135                   11351      4   159
# 136                   11426      4   218
# 137                   11427      3   218
# 144                   11955      4    31
# 145                   12271      5   180
# 160                   13367      6     9
# 168                   14361      1    80
# 174                   15296      2    63
# 181                   15706      3   215
# 187                   16509      1  6275
# 188                   16735      1    37
# 189                   16787      1    58
# 191                   16814      1   194
# 196                   19115      1    43
# 200                   20001     10   235
# 202                   20115     30  2223
# 204                   20214      6    32
# 205                   20473      5   919
# 208                   20940     53  3910
# 212                   21412      1    44
# 213                   21508      7    17
# 218                   22122      2    78
# 219                   22258      4     5
# 225                   22909      6    11
# 228                   23688      3   112
# 244                   26134      1    25
# 245                   26415      1     7
# 248                   26806      1     6
# 253                   27750      6     2
# 284                   29422      1    22
# 286                   29470      1    40
# 303                   33287     19    41
# 304                   33363      9   444
# 305                   33489      3    11
# 306                   33490      9    13
# 307                   33491     20   104
# 309                   33650      5    31
# 310                   33651     14    84
# 311                   33652      4    41
# 313                   33657     15    56
# 314                   33659      7    41
# 315                   33660      5    19
# 316                   33661      6    12
# 317                   33662      9    30
# 318                   33665      1     0
# 319                   33666      3     0
# 320                   33667     19    21
# 321                   33668     12    29
# 322                   33763      1    89
# 358                   37457      8    43
# 385                   42473      1   217
# 395                   45474      3    90
# 403                   47787      1    13
# 528                  131621      1     2
# 549                  140443      1    14
# 620                  262983     21    37
# 694                  266525      1     3
# 765                  396955      1     9

# %%
manrs_origin_either['valid_percent'] = manrs_origin_either[True]/(manrs_origin_either[False] + manrs_origin_either[True])*100

# %%
manrs_origin_either['company'] = manrs_origin_either['originasn_id'].apply(lambda x: manrs_org[x])

# %%
non_manrs_origin_either['valid_percent'] = non_manrs_origin_either[True]/(non_manrs_origin_either[False] + non_manrs_origin_either[True])*100

# %%
small_manrs_origin_either = manrs_origin_either[manrs_origin_either.originasn_id.isin(small)]
medium_manrs_origin_either = manrs_origin_either[manrs_origin_either.originasn_id.isin(medium)]
large_manrs_origin_either = manrs_origin_either[manrs_origin_either.originasn_id.isin(large)]
small_non_manrs_origin_either = non_manrs_origin_either[non_manrs_origin_either.originasn_id.isin(small)]
medium_non_manrs_origin_either = non_manrs_origin_either[non_manrs_origin_either.originasn_id.isin(medium)]
large_non_manrs_origin_either = non_manrs_origin_either[non_manrs_origin_either.originasn_id.isin(large)]

# %% [markdown]
# ## **Non-conformant MANRS ASes in the Network Operators Program**
#
# An AS is non-conformant if it announces less than **90%** prefixes that are either RPKI valid or IRR valid

# %%
small_manrs_origin_either[(small_manrs_origin_either.originasn_id.isin(manrs)) & (small_manrs_origin_either.valid_percent < 90)]
# Out:
# either_status  originasn_id  False  True  valid_percent  \
# 144                   11955      4    31      88.571429
# 245                   26415      1     7      87.500000
# 318                   33665      1     0       0.000000
# 528                  131621      1     2      66.666667
# 620                  262983     21    37      63.793103
#
# either_status                                                org  \
# 144                                       Charter Communications
# 245                                                     Verisign
# 318                                                      Comcast
# 528            Taiwan Computer Emergency Response Team / Coor...
# 620                                                 Net Barretos
#
# either_status                                            company
# 144                                       Charter Communications
# 245                                                     Verisign
# 318                                                      Comcast
# 528            Taiwan Computer Emergency Response Team / Coor...
# 620                                                 Net Barretos

# %%
medium_manrs_origin_either[(medium_manrs_origin_either.originasn_id.isin(manrs)) & (medium_manrs_origin_either.valid_percent < 90)]
# Out:
# either_status  originasn_id  False  True  valid_percent  \
# 75                     5607      4    31      88.571429
# 83                     7016     13    38      74.509804
# 90                     7725      5    36      87.804878
# 98                     7922     94   220      70.063694
# 160                   13367      6     9      60.000000
# 204                   20214      6    32      84.210526
# 213                   21508      7    17      70.833333
# 219                   22258      4     5      55.555556
# 225                   22909      6    11      64.705882
# 248                   26806      1     6      85.714286
# 253                   27750      6     2      25.000000
# 303                   33287     19    41      68.333333
# 305                   33489      3    11      78.571429
# 306                   33490      9    13      59.090909
# 309                   33650      5    31      86.111111
# 313                   33657     15    56      78.873239
# 314                   33659      7    41      85.416667
# 315                   33660      5    19      79.166667
# 316                   33661      6    12      66.666667
# 317                   33662      9    30      76.923077
# 319                   33666      3     0       0.000000
# 320                   33667     19    21      52.500000
# 321                   33668     12    29      70.731707
# 358                   37457      8    43      84.313725
# 694                  266525      1     3      75.000000
#
# either_status                                        org  \
# 75                                                   Sky
# 83                                               Comcast
# 90                                               Comcast
# 98                                               Comcast
# 160                                              Comcast
# 204                                              Comcast
# 213                                              Comcast
# 219                                              Comcast
# 225                                              Comcast
# 248            Saskatchewan Research Network Inc. (SRNET
# 253                                             RedCLARA
# 303                                              Comcast
# 305                                              Comcast
# 306                                              Comcast
# 309                                              Comcast
# 313                                              Comcast
# 314                                              Comcast
# 315                                              Comcast
# 316                                              Comcast
# 317                                              Comcast
# 319                                              Comcast
# 320                                              Comcast
# 321                                              Comcast
# 358                                      Telkom Internet
# 694                                               MAXNET
#
# either_status                                    company
# 75                                                   Sky
# 83                                               Comcast
# 90                                               Comcast
# 98                                               Comcast
# 160                                              Comcast
# 204                                              Comcast
# 213                                              Comcast
# 219                                              Comcast
# 225                                              Comcast
# 248            Saskatchewan Research Network Inc. (SRNET
# 253                                             RedCLARA
# 303                                              Comcast
# 305                                              Comcast
# 306                                              Comcast
# 309                                              Comcast
# 313                                              Comcast
# 314                                              Comcast
# 315                                              Comcast
# 316                                              Comcast
# 317                                              Comcast
# 319                                              Comcast
# 320                                              Comcast
# 321                                              Comcast
# 358                                      Telkom Internet
# 694                                               MAXNET

# %%
large_manrs_origin_either[(large_manrs_origin_either.originasn_id.isin(manrs)) & (large_manrs_origin_either.valid_percent < 90)]
# Out:
# either_status  originasn_id  False  True  valid_percent  \
# 8                       174   1283  2231      63.488902
# 23                     1221    146   214      59.444444
# 53                     3356    439   268      37.906648
# 55                     3549    719    53       6.865285
# 73                     5511      9    69      88.461538
# 78                     6461    177    28      13.658537
# 82                     7015     45    59      56.730769
# 307                   33491     20   104      83.870968
# 310                   33651     14    84      85.714286
#
# either_status                             org                         company
# 8                  Cogent Communications Inc.      Cogent Communications Inc.
# 23                    Telstra Corporation Ltd         Telstra Corporation Ltd
# 53                                CenturyLink                     CenturyLink
# 55                                CenturyLink                     CenturyLink
# 73             Orange - Open Transit Internet  Orange - Open Transit Internet
# 78                                       Zayo                            Zayo
# 82                                    Comcast                         Comcast
# 307                                   Comcast                         Comcast
# 310                                   Comcast                         Comcast

# %%
len(manrs)
# Out:
# 849

# %% [markdown]
# ## **Non-conformant MANRS ASes in the Network Operators Program**
#
# An AS is non-conformant if it announces less than **100%** prefixes that are either RPKI valid or IRR valid

# %%
small_manrs_origin_either[(small_manrs_origin_either.originasn_id.isin(manrscdn)) & (small_manrs_origin_either.valid_percent < 100)]
# Out:
# Empty DataFrame
# Columns: [originasn_id, False, True, valid_percent, org, company]
# Index: []

# %%
medium_manrs_origin_either[(medium_manrs_origin_either.originasn_id.isin(manrscdn)) & (medium_manrs_origin_either.valid_percent < 100)]
# Out:
# either_status  originasn_id  False  True  valid_percent                  org  \
# 187                   16509      1  6275      99.984066  Amazon Web Services
# 208                   20940     53  3910      98.662629  Akamai Technologies
#
# either_status              company
# 187            Amazon Web Services
# 208            Akamai Technologies

# %%
large_manrs_origin_either[(large_manrs_origin_either.originasn_id.isin(manrscdn)) & (large_manrs_origin_either.valid_percent < 100)]
# Out:
# either_status  originasn_id  False  True  valid_percent    org company
# 205                   20473      5   919      99.458874  Vultr   Vultr

# %% [markdown]
# ## Case studies
#
# In Table 1 in the paper, ISP1-3 and CDN1-3 are the companies:

# %% [markdown]
# ### ISP1: comcast case

# %%
comcast = manrs_origin_either[manrs_origin_either.org == 'Comcast']

# %%
manrs_origin[manrs_origin.prefix == '104.243.67.0/24']
# Out:
#                  id                 timebin           prefix  hege  af  \
# 5165310  1411223304  2022-05-01 00:00:00+00  104.243.67.0/24   1.0   4
#
#          visibility rpki_status irr_status delegated_prefix_status  \
# 5165310       100.0    NotFound    Invalid                assigned
#
#         delegated_asn_status           descr moas  asn_id country_id  \
# 5165310             assigned  EZZI.net ROUTE    f    7922         US
#
#          originasn_id nettype  either_status
# 5165310          7922     ISP          False

# %%
comcast[comcast.valid_percent < 90]
# Out:
# either_status  originasn_id  False  True  valid_percent      org
# 82                     7015     45    59      56.730769  Comcast
# 83                     7016     13    38      74.509804  Comcast
# 90                     7725      5    36      87.804878  Comcast
# 98                     7922     94   220      70.063694  Comcast
# 160                   13367      6     9      60.000000  Comcast
# 204                   20214      6    32      84.210526  Comcast
# 213                   21508      7    17      70.833333  Comcast
# 219                   22258      4     5      55.555556  Comcast
# 225                   22909      6    11      64.705882  Comcast
# 303                   33287     19    41      68.333333  Comcast
# 305                   33489      3    11      78.571429  Comcast
# 306                   33490      9    13      59.090909  Comcast
# 307                   33491     20   104      83.870968  Comcast
# 309                   33650      5    31      86.111111  Comcast
# 310                   33651     14    84      85.714286  Comcast
# 313                   33657     15    56      78.873239  Comcast
# 314                   33659      7    41      85.416667  Comcast
# 315                   33660      5    19      79.166667  Comcast
# 316                   33661      6    12      66.666667  Comcast
# 317                   33662      9    30      76.923077  Comcast
# 318                   33665      1     0       0.000000  Comcast
# 319                   33666      3     0       0.000000  Comcast
# 320                   33667     19    21      52.500000  Comcast
# 321                   33668     12    29      70.731707  Comcast

# %%
manrs_origin[manrs_origin.originasn_id.isin(comcast.originasn_id)].groupby(['originasn_id', 'irr_status', 'rpki_status']).size().unstack(fill_value=0)
# Out:
# rpki_status                         Invalid  NotFound  Valid
# originasn_id irr_status
# 7015         Invalid                      0        43     58
#              NotFound                     0         2      0
#              Valid                        0         1      0
# 7016         Invalid                      0        10     36
#              NotFound                     0         3      0
#              Valid                        0         2      0
# 7725         Invalid                      0         5     29
#              Valid                        0         7      0
# 7922         Invalid                      0        79     31
#              Invalid,more-specific        0         0     10
#              NotFound                     0        15      1
#              Valid                        0         6    172
# 11025        Invalid                      0         0      2
#              Invalid,more-specific        0         0      5
#              Valid                        0         0      3
# 13367        Invalid                      0         5      9
#              NotFound                     0         1      0
# 20214        Invalid                      0         6     30
#              Valid                        0         2      0
# 21508        Invalid                      0         7     15
#              Valid                        0         2      0
# 22258        Invalid                      0         4      3
#              Valid                        0         2      0
# 22909        Invalid                      0         6     11
# 33287        Invalid                      0        17     40
#              NotFound                     0         2      0
#              Valid                        0         1      0
# 33489        Invalid                      0         3     11
# 33490        Invalid                      0         9     13
# 33491        Invalid                      0        20    103
#              Invalid,more-specific        0         1      0
# 33650        Invalid                      0         3     25
#              NotFound                     0         2      0
#              Valid                        0         6      0
# 33651        Invalid                      0        13     76
#              NotFound                     0         1      0
#              Valid                        0         8      0
# 33652        Invalid                      0         2     39
#              NotFound                     0         2      0
#              Valid                        0         2      0
# 33654        Invalid                      0         0      1
# 33657        Invalid                      0        15     50
#              NotFound                     0         0      2
#              Valid                        0         4      0
# 33659        Invalid                      1         4     36
#              NotFound                     0         2      0
#              Valid                        0         5      0
# 33660        Invalid                      0         5     19
# 33661        Invalid                      0         5     12
#              NotFound                     0         1      0
# 33662        Invalid                      0         7     29
#              NotFound                     0         2      0
#              Valid                        0         0      1
# 33665        Invalid                      0         1      0
# 33666        Invalid                      0         3      0
# 33667        Invalid                      0        18     20
#              NotFound                     0         1      0
#              Valid                        0         1      0
# 33668        Invalid                      0        11     27
#              NotFound                     0         1      0
#              Valid                        0         2      0
# 36733        Valid                        0         0      1

# %% [markdown]
# ### CDN1: akamai case

# %%
akamai = manrs_origin_either[manrs_origin_either.org == 'Akamai Technologies']

# %%
akamai
# Out:
# either_status  originasn_id  False  True  valid_percent                  org
# 208                   20940     53  3910      98.662629  Akamai Technologies

# %%
manrs_origin[(manrs_origin.originasn_id == 20940) & (manrs_origin.rpki_status.str.contains('Invalid'))]
# Out:
#                  id                 timebin           prefix      hege  af  \
# 705730   1415683351  2022-05-01 00:00:00+00  200.60.190.0/24  0.360544   4
# 705744   1415683337  2022-05-01 00:00:00+00  200.60.136.0/23  0.360544   4
# 3484956  1412903885  2022-05-01 00:00:00+00  200.60.136.0/24  0.360544   4
#
#          visibility rpki_status irr_status delegated_prefix_status  \
# 705730    36.065574     Invalid    Invalid                assigned
# 705744    36.065574     Invalid    Invalid                assigned
# 3484956   36.065574     Invalid    Invalid                assigned
#
#         delegated_asn_status  \
# 705730              assigned
# 705744              assigned
# 3484956             assigned
#
#                                                      descr moas  asn_id  \
# 705730                       Proxy-registered route object    f   20940
# 705744   UniRed - Infointernet - RED_36\nTelefonica Dat...    f   20940
# 3484956  UniRed - Infointernet - RED_36\nTelefonica Dat...    f   20940
#
#         country_id  originasn_id nettype  either_status
# 705730          PE         20940     CDN          False
# 705744          PE         20940     CDN          False
# 3484956         PE         20940     CDN          False

# %%
non_manrs_origin[non_manrs_origin.originasn_id==34164].groupby(['originasn_id', 'rpki_status', 'irr_status']).size().unstack(fill_value=0)
# Out:
# irr_status                Invalid  Invalid,more-specific  NotFound  Valid
# originasn_id rpki_status
# 34164        NotFound          13                     19         1    118
#              Valid              0                      0         0     15

# %% [markdown]
# ### CDN2: amazon case

# %%
amazon = manrs_origin_either[manrs_origin_either.org == 'Amazon Web Services']

# %%
manrs_origin[manrs_origin.originasn_id.isin(amazon.originasn_id)]
# Out:
#                  id                 timebin           prefix  hege  af  \
# 1152144  1415236935  2022-05-01 00:00:00+00  52.124.231.0/24   1.0   4
# 1152149  1415236930  2022-05-01 00:00:00+00  13.225.121.0/24   1.0   4
# 1155353  1415234156  2022-05-01 00:00:00+00    65.8.136.0/22   1.0   4
# 1189615  1415199894  2022-05-01 00:00:00+00   52.85.227.0/24   1.0   4
# 1189621  1415199888  2022-05-01 00:00:00+00  13.225.128.0/21   1.0   4
# ...             ...                     ...              ...   ...  ..
# 5294465  1411095044  2022-05-01 00:00:00+00   15.197.13.0/24   1.0   4
# 5294469  1411095040  2022-05-01 00:00:00+00    15.193.0.0/24   1.0   4
# 5294472  1411095037  2022-05-01 00:00:00+00   15.177.89.0/24   1.0   4
# 5294474  1411095035  2022-05-01 00:00:00+00    15.161.0.0/16   1.0   4
# 5294477  1411095032  2022-05-01 00:00:00+00  15.158.103.0/24   1.0   4
#
#          visibility rpki_status             irr_status  \
# 1152144   99.453552       Valid                  Valid
# 1152149   98.907104       Valid                  Valid
# 1155353   99.453552       Valid  Invalid,more-specific
# 1189615   99.453552       Valid                  Valid
# 1189621   99.453552       Valid                  Valid
# ...             ...         ...                    ...
# 5294465   98.907104       Valid                  Valid
# 5294469  100.000000       Valid                  Valid
# 5294472  100.000000       Valid                  Valid
# 5294474  100.000000       Valid                  Valid
# 5294477  100.000000       Valid                  Valid
#
#         delegated_prefix_status delegated_asn_status                   descr  \
# 1152144                assigned             assigned     Amazon - Cloudfront
# 1152149                assigned             assigned     Amazon - Cloudfront
# 1155353                assigned             assigned   AWS CloudFront Global
# 1189615                assigned             assigned  Amazon - CloudFront TD
# 1189621                assigned             assigned     Amazon - Cloudfront
# ...                         ...                  ...                     ...
# 5294465                assigned             assigned       Amazon EC2 Prefix
# 5294469                assigned             assigned   Amazon EC2 BOM prefix
# 5294472                assigned             assigned   Amazon EC2 DUB prefix
# 5294474                assigned             assigned   Amazon EC2 MXP prefix
# 5294477                assigned             assigned     Amazon - CloudFront
#
#         moas  asn_id country_id  originasn_id nettype  either_status
# 1152144    f   16509         US         16509     CDN           True
# 1152149    f   16509         US         16509     CDN           True
# 1155353    f   16509         US         16509     CDN           True
# 1189615    f   16509         US         16509     CDN           True
# 1189621    f   16509         US         16509     CDN           True
# ...      ...     ...        ...           ...     ...            ...
# 5294465    f   16509         US         16509     CDN           True
# 5294469    f   16509         IN         16509     CDN           True
# 5294472    f   16509         IE         16509     CDN           True
# 5294474    f   16509         IT         16509     CDN           True
# 5294477    f   16509         US         16509     CDN           True
#
# [6276 rows x 17 columns]

# %%
manrs_origin[(manrs_origin.originasn_id == 16509) & (manrs_origin.rpki_status.str.contains('Invalid'))]
# Out:
#                  id                 timebin           prefix      hege  af  \
# 3486203  1412903306  2022-05-01 00:00:00+00  158.51.108.0/24  0.489796   4
#
#          visibility rpki_status irr_status delegated_prefix_status  \
# 3486203   40.983607     Invalid      Valid                assigned
#
#         delegated_asn_status              descr moas  asn_id country_id  \
# 3486203             assigned  Amazon EC2 Prefix    f   16509         US
#
#          originasn_id nettype  either_status
# 3486203         16509     CDN           True

# %% [markdown]
# ### CDN3: vultr case

# %%
vultr = manrs_origin_either[manrs_origin_either.org == 'Vultr']

# %%
manrs_origin[manrs_origin.originasn_id.isin(vultr.originasn_id)]
# Out:
#                  id                 timebin            prefix  hege  af  \
# 780020   1415609136  2022-05-01 00:00:00+00   173.199.83.0/24   1.0   4
# 818054   1415571030  2022-05-01 00:00:00+00   108.61.107.0/24   1.0   4
# 1056279  1415332605  2022-05-01 00:00:00+00  139.180.176.0/21   1.0   4
# 1056297  1415332587  2022-05-01 00:00:00+00   108.61.251.0/24   1.0   4
# 1056451  1415332580  2022-05-01 00:00:00+00   108.61.227.0/24   1.0   4
# ...             ...                     ...               ...   ...  ..
# 5284095  1411105000  2022-05-01 00:00:00+00    140.82.32.0/21   1.0   4
# 5286131  1411102553  2022-05-01 00:00:00+00   108.61.103.0/24   1.0   4
# 5286173  1411102511  2022-05-01 00:00:00+00   108.61.170.0/23   1.0   4
# 5286191  1411102493  2022-05-01 00:00:00+00   108.61.198.0/23   1.0   4
# 5292477  1411096606  2022-05-01 00:00:00+00    45.63.116.0/22   1.0   4
#
#          visibility rpki_status irr_status delegated_prefix_status  \
# 780020   100.000000       Valid      Valid                assigned
# 818054   100.000000       Valid      Valid                assigned
# 1056279   98.907104    NotFound      Valid                assigned
# 1056297   98.907104       Valid      Valid                assigned
# 1056451   98.907104       Valid      Valid                assigned
# ...             ...         ...        ...                     ...
# 5284095  100.000000       Valid      Valid                assigned
# 5286131  100.000000       Valid      Valid                assigned
# 5286173  100.000000       Valid      Valid                assigned
# 5286191  100.000000       Valid      Valid                assigned
# 5292477  100.000000       Valid      Valid                assigned
#
#         delegated_asn_status                                            descr  \
# 780020              assigned  auto-generated route object for 173.199.83.0/24
# 818054              assigned                               Choopa, LLC - POL1
# 1056279             assigned                                   Customer Route
# 1056297             assigned                                  108.61.251.0/24
# 1056451             assigned                                           CHOOPA
# ...                      ...                                              ...
# 5284095             assigned                                   Customer Route
# 5286131             assigned                                          AS20473
# 5286173             assigned                                  108.61.170.0/23
# 5286191             assigned                                    Amsterdam, NL
# 5292477             assigned                                          AS20473
#
#         moas  asn_id country_id  originasn_id nettype  either_status
# 780020     f   20473         PL         20473     CDN           True
# 818054     f   20473         PL         20473     CDN           True
# 1056279    f   20473         AU         20473     CDN           True
# 1056297    f   20473         AU         20473     CDN           True
# 1056451    f   20473         AU         20473     CDN           True
# ...      ...     ...        ...           ...     ...            ...
# 5284095    f   20473         DE         20473     CDN           True
# 5286131    f   20473         NL         20473     CDN           True
# 5286173    f   20473         DE         20473     CDN           True
# 5286191    f   20473         NL         20473     CDN           True
# 5292477    f   20473         DE         20473     CDN           True
#
# [924 rows x 17 columns]

# %%
manrs_origin[(manrs_origin.originasn_id == 20473) & (manrs_origin.rpki_status.str.contains('Invalid'))]
# Out:
# Empty DataFrame
# Columns: [id, timebin, prefix, hege, af, visibility, rpki_status, irr_status, delegated_prefix_status, delegated_asn_status, descr, moas, asn_id, country_id, originasn_id, nettype, either_status]
# Index: []

# %% [markdown]
# ### ISP3: level3 case

# %%
level3 = manrs_origin_either[manrs_origin_either.org == 'CenturyLink']

# %% [markdown]
# ### ISP2: cogent case

# %%
cogent = manrs_origin_either[manrs_origin_either.org == 'Cogent Communications Inc.']
